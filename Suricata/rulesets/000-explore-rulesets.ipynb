# %%
# !pip install wheel idstools pandas numpy
# Out:
# Requirement already satisfied: wheel in /home/vagrant/.venv/lib/python3.8/site-packages (0.37.1)
# Requirement already satisfied: idstools in /home/vagrant/.venv/lib/python3.8/site-packages (0.6.4)
# Requirement already satisfied: pandas in /home/vagrant/.venv/lib/python3.8/site-packages (1.5.0)
# Requirement already satisfied: numpy in /home/vagrant/.venv/lib/python3.8/site-packages (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from pandas) (2022.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/vagrant/.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np

from idstools import rule

import glob
import json
import os
import re

# %% [markdown]
# # ET Open
#
# Download ET Open ruleset.
# ```
# wget https://rules.emergingthreats.net/open/suricata-6.0.1/emerging.rules.tar.gz
# ```
#
# And unpack.
#
# ```
# mkdir /tmp/etopen
# tar -xzf emerging.rules.tar.gz -C /tmp/etopen
# ```

# %%
# !wget -q -O /tmp/etopen.tgz https://rules.emergingthreats.net/open/suricata-6.0.1/emerging.rules.tar.gz

# %%
# !mkdir -p /tmp/etopen
# !tar -xzf /tmp/etopen.tgz -C /tmp/etopen

# %% [markdown]
# Note that this folder in `tmp` must be synced with following `glob` code which constructs a python list of all rule files.

# %%
RULES_LIST_ET_OPEN = glob.glob("/tmp/etopen/rules/*.rules")

# %% [markdown]
# Then use python code to get a organized list of rule files.

# %%
sorted(RULES_LIST_ET_OPEN)
# Out:
# ['/tmp/etopen/rules/3coresec.rules',
#  '/tmp/etopen/rules/botcc.portgrouped.rules',
#  '/tmp/etopen/rules/botcc.rules',
#  '/tmp/etopen/rules/ciarmy.rules',
#  '/tmp/etopen/rules/compromised.rules',
#  '/tmp/etopen/rules/drop.rules',
#  '/tmp/etopen/rules/dshield.rules',
#  '/tmp/etopen/rules/emerging-activex.rules',
#  '/tmp/etopen/rules/emerging-adware_pup.rules',
#  '/tmp/etopen/rules/emerging-attack_response.rules',
#  '/tmp/etopen/rules/emerging-chat.rules',
#  '/tmp/etopen/rules/emerging-coinminer.rules',
#  '/tmp/etopen/rules/emerging-current_events.rules',
#  '/tmp/etopen/rules/emerging-deleted.rules',
#  '/tmp/etopen/rules/emerging-dns.rules',
#  '/tmp/etopen/rules/emerging-dos.rules',
#  '/tmp/etopen/rules/emerging-exploit.rules',
#  '/tmp/etopen/rules/emerging-exploit_kit.rules',
#  '/tmp/etopen/rules/emerging-ftp.rules',
#  '/tmp/etopen/rules/emerging-games.rules',
#  '/tmp/etopen/rules/emerging-hunting.rules',
#  '/tmp/etopen/rules/emerging-icmp.rules',
#  '/tmp/etopen/rules/emerging-icmp_info.rules',
#  '/tmp/etopen/rules/emerging-imap.rules',
#  '/tmp/etopen/rules/emerging-inappropriate.rules',
#  '/tmp/etopen/rules/emerging-info.rules',
#  '/tmp/etopen/rules/emerging-ja3.rules',
#  '/tmp/etopen/rules/emerging-malware.rules',
#  '/tmp/etopen/rules/emerging-misc.rules',
#  '/tmp/etopen/rules/emerging-mobile_malware.rules',
#  '/tmp/etopen/rules/emerging-netbios.rules',
#  '/tmp/etopen/rules/emerging-p2p.rules',
#  '/tmp/etopen/rules/emerging-phishing.rules',
#  '/tmp/etopen/rules/emerging-policy.rules',
#  '/tmp/etopen/rules/emerging-pop3.rules',
#  '/tmp/etopen/rules/emerging-rpc.rules',
#  '/tmp/etopen/rules/emerging-scada.rules',
#  '/tmp/etopen/rules/emerging-scan.rules',
#  '/tmp/etopen/rules/emerging-shellcode.rules',
#  '/tmp/etopen/rules/emerging-smtp.rules',
#  '/tmp/etopen/rules/emerging-snmp.rules',
#  '/tmp/etopen/rules/emerging-sql.rules',
#  '/tmp/etopen/rules/emerging-telnet.rules',
#  '/tmp/etopen/rules/emerging-tftp.rules',
#  '/tmp/etopen/rules/emerging-user_agents.rules',
#  '/tmp/etopen/rules/emerging-voip.rules',
#  '/tmp/etopen/rules/emerging-web_client.rules',
#  '/tmp/etopen/rules/emerging-web_server.rules',
#  '/tmp/etopen/rules/emerging-web_specific_apps.rules',
#  '/tmp/etopen/rules/emerging-worm.rules',
#  '/tmp/etopen/rules/threatview_CS_c2.rules',
#  '/tmp/etopen/rules/tor.rules']

# %% [markdown]
# And parse each rule file with `idstools`, and construct a python dictionary where keys are rule files and values are list of parsed rules.

# %%
# %time PARSED_ET_OPEN = {k: rule.parse_file(k) for k in RULES_LIST_ET_OPEN}
# Out:
# CPU times: user 1.66 s, sys: 131 ms, total: 1.79 s
# Wall time: 1.79 s

# %% [markdown]
# Consider the following parsed rule. Notice how much information can be extracted from it. And reader should already be familiar with sequential option list.

# %%
print(
    json.dumps(
        PARSED_ET_OPEN["/tmp/etopen/rules/emerging-malware.rules"][0], 
        indent=2
    )
)
# Out:
# {
#   "enabled": false,
#   "action": "alert",
#   "direction": "->",
#   "group": null,
#   "gid": 1,
#   "sid": 2009172,
#   "rev": 2,
#   "msg": "ET MALWARE Psyb0t joining an IRC Channel",
#   "flowbits": [
#     "isset,is_proto_irc"
#   ],
#   "metadata": [
#     "created_at 2010_07_30",
#     "updated_at 2010_07_30"
#   ],
#   "references": [
#     "url,www.adam.com.au/bogaurd/PSYB0T.pdf",
#     "url,doc.emergingthreats.net/2009172"
#   ],
#   "classtype": "trojan-activity",
#   "priority": 0,
#   "options": [
#     {
#       "name": "msg",
#       "value": "\"ET MALWARE Psyb0t joining an IRC Channel\""
#     },
#     {
#       "name": "flow",
#       "value": "established,to_server"
#     },
#     {
#       "name": "flowbits",
#       "value": "isset,is_proto_irc"
#     },
#     {
#       "name": "content",
#       "value": "\"JOIN #mipsel\""
#     },
#     {
#       "name": "reference",
#       "value": "url,www.adam.com.au/bogaurd/PSYB0T.pdf"
#     },
#     {
#       "name": "reference",
#       "value": "url,doc.emergingthreats.net/2009172"
#     },
#     {
#       "name": "classtype",
#       "value": "trojan-activity"
#     },
#     {
#       "name": "sid",
#       "value": "2009172"
#     },
#     {
#       "name": "rev",
#       "value": "2"
#     },
#     {
#       "name": "metadata",
#       "value": "created_at 2010_07_30, updated_at 2010_07_30"
#     }
#   ],
#   "raw": "alert tcp $HOME_NET any -> $EXTERNAL_NET any (msg:\"ET MALWARE Psyb0t joining an IRC Channel\"; flow:established,to_server; flowbits:isset,is_proto_irc; content:\"JOIN #mipsel\"; reference:url,www.adam.com.au/bogaurd/PSYB0T.pdf; reference:url,doc.emergingthreats.net/2009172; classtype:trojan-activity; sid:2009172; rev:2; metadata:created_at 2010_07_30, updated_at 2010_07_30;)",
#   "header": "alert tcp $HOME_NET any -> $EXTERNAL_NET any",
#   "flow": "established,to_server",
#   "content": "\"JOIN #mipsel\""
# }

# %% [markdown]
# ## High level view

# %% [markdown]
# Traditional data structures can be difficult for human eyes to grasp. On small scale they are fine, but things become complex if you consider that ET Open contains over 31 **thousand** rules. However, aggregations presented in row-column format can help us out here.
#
# For that, we can use `pandas` scientific package which implements **data frames** in python. Great for data wrangling and exploration. Following block creates a new pandas data frame, and initializes columns of counters per rule file. For now, we're just interested in `total number of rules`, `number of enabled rules` and `number of disabled rules`.

# %%
DF_HIGH_LEVEL = pd.DataFrame()
DF_HIGH_LEVEL["file"] = list(PARSED_ET_OPEN.keys())
DF_HIGH_LEVEL["rules_total_count"] = list([len(v) for v in PARSED_ET_OPEN.values()])
DF_HIGH_LEVEL["rules_disabled_count"] = list([len([item for item in v if not item.enabled]) for v in PARSED_ET_OPEN.values()])
DF_HIGH_LEVEL["rules_enabled_count"] = list([len([item for item in v if item.enabled]) for v in PARSED_ET_OPEN.values()])

# %% [markdown]
# Then present the dataframe sorted by the number of active rules per file.

# %%
DF_HIGH_LEVEL.sort_values(by=["rules_enabled_count"], ascending=False)
# Out:
#                                                  file  rules_total_count  \
# 10           /tmp/etopen/rules/emerging-malware.rules              12180
# 26  /tmp/etopen/rules/emerging-web_specific_apps.r...               5600
# 21          /tmp/etopen/rules/emerging-phishing.rules               2249
# 18           /tmp/etopen/rules/emerging-exploit.rules               1773
# 30              /tmp/etopen/rules/emerging-info.rules               1283
# 46           /tmp/etopen/rules/emerging-hunting.rules               1051
# 16                        /tmp/etopen/rules/tor.rules                987
# 35            /tmp/etopen/rules/emerging-policy.rules               1209
# 41    /tmp/etopen/rules/emerging-mobile_malware.rules                913
# 37        /tmp/etopen/rules/emerging-web_server.rules                796
# 14        /tmp/etopen/rules/emerging-adware_pup.rules               1189
# 12   /tmp/etopen/rules/emerging-attack_response.rules                690
# 48        /tmp/etopen/rules/emerging-web_client.rules                809
# 15       /tmp/etopen/rules/emerging-exploit_kit.rules               1197
# 9            /tmp/etopen/rules/emerging-netbios.rules                474
# 47              /tmp/etopen/rules/emerging-scan.rules                360
# 23       /tmp/etopen/rules/emerging-user_agents.rules                318
# 1                /tmp/etopen/rules/emerging-sql.rules                311
# 39           /tmp/etopen/rules/emerging-activex.rules                534
# 44               /tmp/etopen/rules/emerging-ja3.rules                135
# 19                     /tmp/etopen/rules/ciarmy.rules                100
# 42               /tmp/etopen/rules/emerging-p2p.rules                119
# 27    /tmp/etopen/rules/emerging-current_events.rules                231
# 43               /tmp/etopen/rules/emerging-rpc.rules                117
# 13              /tmp/etopen/rules/emerging-chat.rules                 90
# 49         /tmp/etopen/rules/emerging-shellcode.rules                186
# 40               /tmp/etopen/rules/emerging-dos.rules                114
# 45               /tmp/etopen/rules/emerging-ftp.rules                115
# 8                        /tmp/etopen/rules/drop.rules                 36
# 28               /tmp/etopen/rules/emerging-dns.rules                 49
# 31                   /tmp/etopen/rules/3coresec.rules                 29
# 32         /tmp/etopen/rules/emerging-coinminer.rules                 29
# 33                      /tmp/etopen/rules/botcc.rules                 25
# 5                 /tmp/etopen/rules/compromised.rules                 23
# 36              /tmp/etopen/rules/emerging-misc.rules                 62
# 2              /tmp/etopen/rules/emerging-games.rules                 85
# 20             /tmp/etopen/rules/emerging-scada.rules                 18
# 6               /tmp/etopen/rules/emerging-imap.rules                 33
# 25              /tmp/etopen/rules/emerging-voip.rules                 21
# 24              /tmp/etopen/rules/emerging-snmp.rules                 33
# 3               /tmp/etopen/rules/emerging-smtp.rules                 23
# 22         /tmp/etopen/rules/emerging-icmp_info.rules                 66
# 34              /tmp/etopen/rules/emerging-tftp.rules                 20
# 11           /tmp/etopen/rules/threatview_CS_c2.rules                 11
# 4               /tmp/etopen/rules/emerging-worm.rules                 19
# 50              /tmp/etopen/rules/emerging-pop3.rules                 20
# 29            /tmp/etopen/rules/emerging-telnet.rules                 10
# 17                    /tmp/etopen/rules/dshield.rules                  1
# 0           /tmp/etopen/rules/botcc.portgrouped.rules                  0
# 38           /tmp/etopen/rules/emerging-deleted.rules               3323
# 7               /tmp/etopen/rules/emerging-icmp.rules                 39
# 51     /tmp/etopen/rules/emerging-inappropriate.rules                 25
#
#     rules_disabled_count  rules_enabled_count
# 10                  2545                 9635
# 26                   749                 4851
# 21                   106                 2143
# 18                   320                 1453
# 30                    60                 1223
# 46                    38                 1013
# 16                     0                  987
# 35                   327                  882
# 41                    78                  835
# 37                   147                  649
# 14                   586                  603
# 12                   100                  590
# 48                   307                  502
# 15                   805                  392
# 9                     82                  392
# 47                    75                  285
# 23                    50                  268
# 1                    120                  191
# 39                   349                  185
# 44                     6                  129
# 19                     0                  100
# 42                    31                   88
# 27                   147                   84
# 43                    34                   83
# 13                    21                   69
# 49                   124                   62
# 40                    54                   60
# 45                    58                   57
# 8                      0                   36
# 28                    19                   30
# 31                     0                   29
# 32                     3                   26
# 33                     0                   25
# 5                      0                   23
# 36                    41                   21
# 2                     66                   19
# 20                     0                   18
# 6                     16                   17
# 25                     5                   16
# 24                    17                   16
# 3                      9                   14
# 22                    52                   14
# 34                     7                   13
# 11                     0                   11
# 4                     10                    9
# 50                    11                    9
# 29                     2                    8
# 17                     0                    1
# 0                      0                    0
# 38                  3323                    0
# 7                     39                    0
# 51                    25                    0

# %% [markdown]
# Each column of counters is a vector that can be summed up for total counts.

# %%
print("Enabled: {} Disabled: {} Total: {}".format(
    DF_HIGH_LEVEL.rules_enabled_count.sum(),
    DF_HIGH_LEVEL.rules_disabled_count.sum(),
    DF_HIGH_LEVEL.rules_total_count.sum(),
))
# Out:
# Enabled: 28166 Disabled: 10964 Total: 39130

# %% [markdown]
# ## Dig into specific rule files and threats

# %% [markdown]
# Okay, now let's try to get information about some rules themselves.
#
# Before getting started, `idstools` parses some information that is not terribly useful (like `action`, `direction`) while leaving other more useful data pieces unparsed. Looking specifically the `header` field for `protocol`, `src_net` and `dest_net`. Following helper function can parse that information.

# %%
def extract_header(header: str) -> dict:
    split = header.split()
    return {
        "proto": split[1],
        "src_net": split[2],
        "src_port": split[3],
        "dest_net": split[5],
        "dest_port": split[6]
    }

# %% [markdown]
# Then build a list of all rules while adding cleaned up filename and that `header` information to dictionary.

# %%
ALL_ET_OPEN_RULES = []

for filename, rules in PARSED_ET_OPEN.items():
    for r in rules:
        r["file"] = os.path.basename(filename)
        r = {**r, **extract_header(r.get("header"))}
        ALL_ET_OPEN_RULES.append(r)

# %% [markdown]
# And rather than attempting to inspect 31k element list, we'll turn the whole thing into a dataframe.

# %%
DF_ET_OPEN_ALL = pd.DataFrame(ALL_ET_OPEN_RULES)

# %% [markdown]
# Filter for only enabled rules. Rules are always commented for a reason!
# * false positives;
# * bad performance;
# * just out of date and irrelevant;

# %%
DF_ET_OPEN_ALL = DF_ET_OPEN_ALL.loc[DF_ET_OPEN_ALL.enabled == True]

# %% [markdown]
# And get a quick peek of ruleset. Just to see what we can work on. Clearly we need to do more filtering and a proper selection of columns. All those *sticky buffer* and *content modifier* columns are totally useless. That's because they always apply to `content` keyword and have no values themselves. Thus, all those vectors are empty.

# %%
DF_ET_OPEN_ALL.head(5)
# Out:
#    enabled action direction group  gid      sid  rev  \
# 1     True  alert        ->  None    1  2102003    9
# 2     True  alert        ->  None    1  2101775    4
# 3     True  alert        ->  None    1  2101776    4
# 5     True  alert        ->  None    1  2101674    6
# 7     True  alert        ->  None    1  2103152    4
#
#                                                  msg flowbits  \
# 1           GPL SQL Slammer Worm propagation attempt       []
# 2                   GPL SQL MYSQL root login attempt       []
# 3               GPL SQL MYSQL show databases attempt       []
# 5  GPL SQL connect_data remote version detection ...       []
# 7        GPL SQL sa brute force failed login attempt       []
#
#                                          metadata  ... icmp_seq ja3_hash  \
# 1  [created_at 2010_09_23, updated_at 2010_09_23]  ...      NaN      NaN
# 2  [created_at 2010_09_23, updated_at 2010_09_23]  ...      NaN      NaN
# 3  [created_at 2010_09_23, updated_at 2010_09_23]  ...      NaN      NaN
# 5  [created_at 2010_09_23, updated_at 2010_09_23]  ...      NaN      NaN
# 7  [created_at 2010_09_23, updated_at 2010_09_23]  ...      NaN      NaN
#
#    ssh.software http_referer ja3s.hash tls.fingerprint ja3.hash ja3.string  \
# 1           NaN          NaN       NaN             NaN      NaN        NaN
# 2           NaN          NaN       NaN             NaN      NaN        NaN
# 3           NaN          NaN       NaN             NaN      NaN        NaN
# 5           NaN          NaN       NaN             NaN      NaN        NaN
# 7           NaN          NaN       NaN             NaN      NaN        NaN
#
#    ftpbounce sameip
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 5        NaN    NaN
# 7        NaN    NaN
#
# [5 rows x 145 columns]

# %% [markdown]
# So, we'll build a more consise dataframe. with only those columns we are about. List is not exhaustive and just my selection. **Decide what is relevant to you!**

# %%
CORE_COLS = ["proto", "src_net", "dest_net", "sid", "rev", "msg", "file", "flowbits", "metadata", "references", "flow", "raw"]

# %%
DF_ET_OPEN_CONSISE = DF_ET_OPEN_ALL.loc[:,  CORE_COLS]

# %% [markdown]
# Notice that our dataframe peek was truncated. This is to avoid exploding your browser, as dataframes can be very big. Following optins can disable that to reveal more information. **But use them with care, make sure you don't call 31k row printout into your browser!**

# %%
pd.set_option('display.max_colwidth', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
#pd.set_option('display.min_rows', None)
pd.set_option('display.width', None)

# %% [markdown]
# Some rule categories are small and can be shown as-is. Rather than creating separate data structures, we'll go data science way and keep everything in one dataframe. Remember, we are exploring, so we never know where that exploration will lead. Better to keep everything at arms reach and just filter if needed. Rely on intermediete data before reaching your goal.
#
# So, to see into `emerging-worm` category, we can simply filter for that file name. Furthermore, we can sort values to make the information easier to grasp. Sorting by rule directionality is already a good trick to visually group rules.

# %%
DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE.file.str.contains("emerging-worm.rules")] \
    .sort_values(by=["src_net", "dest_net"])
# Out:
#     proto    src_net       dest_net      sid  rev  \
# 425   udp  $HOME_NET  $EXTERNAL_NET  2102004    8
# 428   tcp  $HOME_NET  $EXTERNAL_NET  2017404    3
# 430  http  $HOME_NET  $EXTERNAL_NET  2014402    3
# 433  http  $HOME_NET  $EXTERNAL_NET  2012201    5
# 435  http  $HOME_NET  $EXTERNAL_NET  2008020    6
# 437  http  $HOME_NET  $EXTERNAL_NET  2012739    4
# 431  http        any      $HOME_NET  2018132    5
# 432  http        any      $HOME_NET  2018155    5
# 434  http        any      $HOME_NET  2018131    6
#
#                                                                             msg  \
# 425                          GPL WORM Slammer Worm propagation attempt OUTBOUND
# 428                                               ET WORM W32/Njw0rm CnC Beacon
# 430                                          ET WORM W32/Rimecud wg.txt Checkin
# 433  ET WORM Possible Worm Sohanad.Z or Other Infection Request for setting.nql
# 435                                     ET WORM Win32.Socks.s HTTP Post Checkin
# 437                                                ET WORM Rimecud Worm checkin
# 431                                            ET WORM TheMoon.linksys.router 2
# 432                                            ET WORM TheMoon.linksys.router 3
# 434                                            ET WORM TheMoon.linksys.router 1
#
#                     file flowbits  \
# 425  emerging-worm.rules       []
# 428  emerging-worm.rules       []
# 430  emerging-worm.rules       []
# 433  emerging-worm.rules       []
# 435  emerging-worm.rules       []
# 437  emerging-worm.rules       []
# 431  emerging-worm.rules       []
# 432  emerging-worm.rules       []
# 434  emerging-worm.rules       []
#
#                                                                                                                                                                                                                                                                                                     metadata  \
# 425                                                                                                                                                                                                                                                           [created_at 2010_09_23, updated_at 2010_09_23]
# 428  [attack_target Client_Endpoint, created_at 2013_08_31, deployment Perimeter, former_category WORM, signature_severity Major, tag c2, updated_at 2013_08_31, mitre_tactic_id TA0011, mitre_tactic_name Command_And_Control, mitre_technique_id T1041, mitre_technique_name Exfiltration_Over_C2_Channel]
# 430                                                                                                                                                                                                                                                           [created_at 2012_03_20, updated_at 2020_04_21]
# 433                                                                                                                                                                                                                                                           [created_at 2011_01_17, updated_at 2020_08_04]
# 435                                                                                                                                                                                                                                                           [created_at 2010_07_30, updated_at 2020_08_18]
# 437                                                                                                                                                                                                                                                           [created_at 2011_04_29, updated_at 2020_10_13]
# 431                                                                                                                                                                                                                                                           [created_at 2014_02_13, updated_at 2020_07_07]
# 432                                                                                                                                                                                                                                                           [created_at 2014_02_19, updated_at 2020_07_07]
# 434                                                                                                                                                                                                                                                           [created_at 2014_02_13, updated_at 2020_08_18]
#
#                                                                                                                                                                              references  \
# 425                                                                                  [bugtraq,5310, bugtraq,5311, cve,2002-0649, nessus,11214, url,vil.nai.com/vil/content/v_99992.htm]
# 428  [url,www.fireeye.com/blog/technical/malware-research/2013/08/njw0rm-brother-from-the-same-mother.html, md5,4c60493b14c666c56db163203e819272, md5,b0e1d20accd9a2ed29cdacb803e4a89d]
# 430      [md5,a89f7289d5cce821a194542e90026082, md5,fd56ce176889d4fbe588760a1da6462b, url,www.microsoft.com/security/portal/Threat/Encyclopedia/Entry.aspx?Name=Worm%3AWin32%2FRimecud]
# 433                                                                                                                                              [md5,a70aad8f27957702febfa162556dc5b5]
# 435                                                                                                                                               [url,doc.emergingthreats.net/2008020]
# 437                                                                                                                                              [md5,9623efa133415d19c941ef92a4f921fc]
# 431                                                               [url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630, url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/]
# 432                           [url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630, url,exploit-db.com/exploits/31683/, url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/]
# 434                                                                                                                         [url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630]
#
#                       flow  \
# 425                    NaN
# 428  established,to_server
# 430  established,to_server
# 433  established,to_server
# 435  established,to_server
# 437  established,to_server
# 431  to_server,established
# 432  to_server,established
# 434            established
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 raw
# 425                                                                                                                                                                                                                                                                                                   alert udp $HOME_NET any -> $EXTERNAL_NET 1434 (msg:"GPL WORM Slammer Worm propagation attempt OUTBOUND"; content:"|04|"; depth:1; content:"|81 F1 03 01 04 9B 81 F1|"; content:"sock"; content:"send"; reference:bugtraq,5310; reference:bugtraq,5311; reference:cve,2002-0649; reference:nessus,11214; reference:url,vil.nai.com/vil/content/v_99992.htm; classtype:misc-attack; sid:2102004; rev:8; metadata:created_at 2010_09_23, updated_at 2010_09_23;)
# 428  alert tcp $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM W32/Njw0rm CnC Beacon"; flow:established,to_server; content:"lv0njxq80"; depth:9; content:"njxq80"; distance:0; reference:url,www.fireeye.com/blog/technical/malware-research/2013/08/njw0rm-brother-from-the-same-mother.html; reference:md5,4c60493b14c666c56db163203e819272; reference:md5,b0e1d20accd9a2ed29cdacb803e4a89d; classtype:command-and-control; sid:2017404; rev:3; metadata:attack_target Client_Endpoint, created_at 2013_08_31, deployment Perimeter, former_category WORM, signature_severity Major, tag c2, updated_at 2013_08_31, mitre_tactic_id TA0011, mitre_tactic_name Command_And_Control, mitre_technique_id T1041, mitre_technique_name Exfiltration_Over_C2_Channel;)
# 430                                                                                                                                                                                                                                                                                            alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM W32/Rimecud wg.txt Checkin"; flow:established,to_server; http.uri; content:"/wg.txt"; reference:md5,a89f7289d5cce821a194542e90026082; reference:md5,fd56ce176889d4fbe588760a1da6462b; reference:url,www.microsoft.com/security/portal/Threat/Encyclopedia/Entry.aspx?Name=Worm%3AWin32%2FRimecud; classtype:trojan-activity; sid:2014402; rev:3; metadata:created_at 2012_03_20, updated_at 2020_04_21;)
# 433                                                                                                                                                                                                                                                                                                                                                                                                   alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM Possible Worm Sohanad.Z or Other Infection Request for setting.nql"; flow:established,to_server; http.uri; content:"/setting.nql"; nocase; reference:md5,a70aad8f27957702febfa162556dc5b5; classtype:trojan-activity; sid:2012201; rev:5; metadata:created_at 2011_01_17, updated_at 2020_08_04;)
# 435                                                                                                                                                                                                                                                                                                                                                        alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM Win32.Socks.s HTTP Post Checkin"; flow:established,to_server; http.method; content:"POST"; http.uri; content:".php"; http.request_body; content:"proc=[System Process]|0a|"; depth:22; reference:url,doc.emergingthreats.net/2008020; classtype:trojan-activity; sid:2008020; rev:6; metadata:created_at 2010_07_30, updated_at 2020_08_18;)
# 437                                                                                                                                                                                                                                                                                                                               alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM Rimecud Worm checkin"; flow:established,to_server; http.method; content:"GET"; http.uri; content:"/taskx.txt"; fast_pattern; http.user_agent; content:"Mozilla/3.0 (compatible|3b 20|Indy Library)"; depth:38; reference:md5,9623efa133415d19c941ef92a4f921fc; classtype:trojan-activity; sid:2012739; rev:4; metadata:created_at 2011_04_29, updated_at 2020_10_13;)
# 431                                                                                                                                                                                                                                                                                                                                      alert http any any -> $HOME_NET 8080 (msg:"ET WORM TheMoon.linksys.router 2"; flow:to_server,established; http.method; content:"POST"; http.uri; content:"/tmUnblock.cgi"; reference:url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630; reference:url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/; classtype:trojan-activity; sid:2018132; rev:5; metadata:created_at 2014_02_13, updated_at 2020_07_07;)
# 432                                                                                                                                                                                                                                                                                       alert http any any -> $HOME_NET 8080 (msg:"ET WORM TheMoon.linksys.router 3"; flow:to_server,established; http.method; content:"POST"; http.uri; content:"/hndUnblock.cgi"; reference:url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630; reference:url,exploit-db.com/exploits/31683/; reference:url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/; classtype:trojan-activity; sid:2018155; rev:5; metadata:created_at 2014_02_19, updated_at 2020_07_07;)
# 434                                                                                                                                                                                                                                                                                                                                                             alert http any any -> $HOME_NET 8080 (msg:"ET WORM TheMoon.linksys.router 1"; flow:established; urilen:7; http.method; content:"GET"; http.uri; content:"/HNAP1/"; http.host; pcre:"/^(?:[0-9]{1,3}\.){3}[0-9]{1,3}$/"; reference:url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630; classtype:trojan-activity; sid:2018131; rev:6; metadata:created_at 2014_02_13, updated_at 2020_08_18;)

# %% [markdown]
# **PS! Jupyter is a data science tool, and thus caters to that audience. This can lead to silly things like formating rule header like mathematical formula**.
#
# However, really good stuff is in `malware` and `mobile_malware` categories. And those are big. Too big to explore with full dumps. So, let's limit the scope only to a *recent hotness*.

# %%
RULES_SUNBURST = DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE.msg.str.contains("SUNBURST", re.IGNORECASE)] \
    .sort_values(by=["proto", "src_net", "dest_net", "msg"]) \
    .drop(columns=["flowbits", "raw", "metadata", "flow"]) \
    .explode("references")

# %% [markdown]
# This is a bit more involved, but in many ways is similar to a database query.
# * First, we locate all rules containing `SUNBURST` keyword. Sometimes this information is in `tag` or `metadata`, but dont count on it. And it's not very consistent.
# * Then we sort values to make the frame visually easier to explore. Pandas even let's us sort by multiple values. That's why I wanted to parse `proto`, `src_net` and `dest_net` from the rule header! With those fields, we get a much better organized view.
# * Then drop some columns (from view) that are just noise:
#   * `flowbits` are not really that relevant for current explorations, rule content should be listed separately anyway
#   * likewise `raw` rule just makes dataframe as a whole more difficult to assess, but it can always be added back if we need to check the content!
#   * `metadata` does not hold much useful information and is a list, which again makes frame messy
#   * `flow` is a bit redundant with sorted `src_net` and `dest_net` view. Good info, but we only have limited screen real-estate
#  * Finally, `references` holds lists, but we can use `explode()` method to unpack each reference to separate row. **This duplicates other rule row elements!** But not a big deal for this case.

# %%
RULES_SUNBURST
# Out:
#      proto    src_net       dest_net      sid  rev  \
# 9285   dns  $HOME_NET            any  2031392    1
# 9284   dns  $HOME_NET            any  2031391    1
# 9282   dns  $HOME_NET            any  2031389    1
# 9283   dns  $HOME_NET            any  2031390    1
# 9281   dns  $HOME_NET            any  2031387    1
# ...    ...        ...            ...      ...  ...
# 9272   tls  $HOME_NET  $EXTERNAL_NET  2031363    1
# 9273   tls  $HOME_NET  $EXTERNAL_NET  2031364    1
# 9271   tls  $HOME_NET  $EXTERNAL_NET  2031362    1
# 9277   tls  $HOME_NET  $EXTERNAL_NET  2031368    1
# 9278   tls  $HOME_NET  $EXTERNAL_NET  2031369    1
#
#                                                                                             msg  \
# 9285               ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to globalnetworkissues .com
# 9284                         ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to kubecloud .com
# 9282                        ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to lcomputers .com
# 9283                      ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to seobundlekit .com
# 9281               ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to solartrackingsystem .net
# ...                                                                                         ...
# 9272  ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (incomeudpate .com in TLS SNI)
# 9273   ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (panhardware .com in TLS SNI)
# 9271   ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (thedoccloud .com in TLS SNI)
# 9277  ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (websitetheme .com in TLS SNI)
# 9278     ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (zupertech .com in TLS SNI)
#
#                         file  \
# 9285  emerging-malware.rules
# 9284  emerging-malware.rules
# 9282  emerging-malware.rules
# 9283  emerging-malware.rules
# 9281  emerging-malware.rules
# ...                      ...
# 9272  emerging-malware.rules
# 9273  emerging-malware.rules
# 9271  emerging-malware.rules
# 9277  emerging-malware.rules
# 9278  emerging-malware.rules
#
#                                                                                                                                        references
# 9285                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 9284                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 9282                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 9283                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 9281                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# ...                                                                                                                                           ...
# 9272  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 9273  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 9271  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 9277  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 9278  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
#
# [62 rows x 8 columns]

# %% [markdown]
# Same exploration can be repeated for other relevant threats. For example, I bet many students are interested in `Cobalt Strike` rules.

# %%
RULES_COBALT_STRIKE = DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE \
    .msg.str.contains("Cobalt Strike|CobaltStrike", re.IGNORECASE)] \
    .drop(columns=["metadata", "flowbits"]) \
    .explode("references") \
    .sort_values(by=["msg"]) \
    .drop(columns=["raw"])

# %%
RULES_COBALT_STRIKE.head()
# Out:
#       proto        src_net   dest_net      sid  rev  \
# 37110   tls  $EXTERNAL_NET  $HOME_NET  2023629    5
# 36559   tls  $EXTERNAL_NET  $HOME_NET  2033396    1
# 36558   tls  $EXTERNAL_NET  $HOME_NET  2033395    1
# 36557   tls  $EXTERNAL_NET  $HOME_NET  2033157    1
# 36560   tls  $EXTERNAL_NET  $HOME_NET  2028832    3
#
#                                                                            msg  \
# 37110  ET HUNTING Suspicious Empty SSL Certificate - Observed in Cobalt Strike
# 36559                              ET JA3 HASH - Possible Cobalt Strike Server
# 36558                              ET JA3 HASH - Possible Cobalt Strike Server
# 36557                              ET JA3 HASH - Possible Cobalt Strike Server
# 36560             ET JA3 Hash - Suspected Cobalt Strike Malleable C2 (ja3s) M1
#
#                          file  \
# 37110  emerging-hunting.rules
# 36559      emerging-ja3.rules
# 36558      emerging-ja3.rules
# 36557      emerging-ja3.rules
# 36560      emerging-ja3.rules
#
#                                                                       references  \
# 37110                                                                        NaN
# 36559    url,thedfirreport.com/2021/07/19/icedid-and-cobalt-strike-vs-antivirus/
# 36558    url,thedfirreport.com/2021/07/19/icedid-and-cobalt-strike-vs-antivirus/
# 36557  url,thedfirreport.com/2021/06/20/from-word-to-lateral-movement-in-1-hour/
# 36560                                                                        NaN
#
#                           flow
# 37110  from_server,established
# 36559                      NaN
# 36558                      NaN
# 36557                      NaN
# 36560  established,from_server

# %% [markdown]
# Here we can see that many rules have multiple references. And, on that note, rules can hold a lot of interesting reading materials! How about we build a reading list.

# %%
TEXT = "\n".join(sorted(
    list(
        RULES_COBALT_STRIKE \
            .loc[RULES_COBALT_STRIKE.fillna("NA") \
                                    .references.str.contains("^url")] \
            .references.unique()
    )
))

# %%
print(TEXT)
# Out:
# url,attack.mitre.org/groups/G0080/
# url,blog.cobaltstrike.com/2015/10/07/named-pipe-pivoting/
# url,blog.malwarebytes.com/threat-analysis/2020/06/multi-stage-apt-attack-drops-cobalt-strike-using-malleable-c2-feature
# url,blog.malwarebytes.com/threat-intelligence/2022/03/new-spear-phishing-campaign-targets-russian-dissidents/
# url,blog.reversinglabs.com/blog/threat-analysis-follina-exploit-powers-live-off-the-land-attacks
# url,blog.talosintelligence.com/2020/06/indigodrop-maldocs-cobalt-strike.html
# url,blog.talosintelligence.com/2021/11/attackers-use-domain-fronting-technique.html
# url,blog.talosintelligence.com/2022/05/mustang-panda-targets-europe.html
# url,cert.gov.ua/article/37704
# url,cert.gov.ua/article/38155
# url,cert.gov.ua/article/39708
# url,cert.gov.ua/article/40559
# url,cert.gov.ua/article/619229
# url,cert.gov.ua/article/703548
# url,cisa.gov/uscert/ncas/alerts/aa21-265a
# url,documents.trendmicro.com/assets/white_papers/wp-earth-baku-an-apt-group-targeting-indo-pacific-countries.pdf
# url,fireeye.com/blog/threat-research/2020/03/the-cycle-of-adversary-pursuit.html
# url,gist.github.com/aaronst/6aa7f61246f53a8dd4befea86e832456
# url,github.com//rsmudge/Malleable-C2-Profiles/blob/master/crimeware/magnitude.profile
# url,github.com/giMini/PowerMemory/blob/master/PowerProcess/Inject-ShellCodeInProcess.ps1
# url,github.com/pan-unit42/tweets/blob/master/2021-04-26-IcedID-with-Cobalt-Strike-IOCs.txt
# url,github.com/pan-unit42/tweets/blob/master/2021-08-09-BazarLoader-and-Cobalt-Strike-IOCs.txt
# url,github.com/pan-unit42/tweets/blob/master/2021-09-13-IOCs-for-TA551-Trickbot-with-Cobalt-Strike-and-DarkVNC.txt
# url,github.com/pan-unit42/tweets/blob/master/2021-11-22-IOCs-for-Contact-Forms-campaign-activity.txt
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/APT/havex.profile
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/APT/meterpreter.profile
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/microsoftupdate_getonly.profile
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/onedrive_getonly.profile
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/oscp.profile
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/rtmp.profile
# url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/safebrowsing.profile
# url,github.com/sophoslabs/IoCs/blob/master/Troj-Miner-AED.csv
# url,github.com/xx0hcd/Malleable-C2-Profiles
# url,go.recordedfuture.com/hubfs/reports/cta-2021-1208.pdf
# url,ics-cert.kaspersky.com/publications/reports/2022/06/27/attacks-on-industrial-control-systems-using-shadowpad/
# url,isc.sans.edu/diary/rss/28448
# url,isc.sans.edu/diary/rss/28752
# url,isc.sans.edu/diary/rss/28824
# url,isc.sans.edu/diary/rss/28884
# url,malware-traffic-analysis.net/2022/07/25/index.html
# url,medium.com/walmartglobaltech/nimar-loader-4f61c090c49e
# url,medium.com/walmartglobaltech/signed-dll-campaigns-as-a-service-7760ac676489
# url,news.sophos.com/en-us/2022/01/19/zloader-installs-remote-access-backdoors-and-delivers-cobalt-strike/
# url,posts.specterops.io/designing-peer-to-peer-command-and-control-ad2c61740456
# url,securelist.com/ghostemperor-from-proxylogon-to-kernel-mode/104407/
# url,sslbl.abuse.ch/ssl-certificates/sha1/ddb59d8cc93688bbf4925c7d27462b70e53225cb/
# url,tarlogic.com/blog/hidding-cobalt-strike-traffic
# url,thedfirreport.com/2021/06/20/from-word-to-lateral-movement-in-1-hour/
# url,thedfirreport.com/2021/07/19/icedid-and-cobalt-strike-vs-antivirus/
# url,thedfirreport.com/2021/08/01/bazarcall-to-conti-ransomware-via-trickbot-and-cobalt-strike/
# url,thedfirreport.com/2021/08/16/trickbot-leads-up-to-fake-1password-installation/
# url,thedfirreport.com/2021/09/13/bazarloader-to-conti-ransomware-in-32-hours/
# url,thedfirreport.com/2021/10/04/bazarloader-and-the-conti-leaks
# url,thedfirreport.com/2021/11/29/continuing-the-bazar-ransomware-story/
# url,thedfirreport.com/2021/12/13/diavol-ransomware/
# url,thedfirreport.com/2022/02/21/qbot-and-zerologon-lead-to-full-domain-compromise/
# url,thedfirreport.com/2022/05/09/seo-poisoning-a-gootloader-story/
# url,thedfirreport.com/2022/08/08/bumblebee-roasts-its-way-to-domain-admin/
# url,threatview.io/Downloads/High-Confidence-CobaltStrike-C2%20-Feeds.txt
# url,tria.ge/220324-p4dl5adghn
# url,twitter.com/BlackLotusLabs/status/1456314419215020043
# url,twitter.com/CyberRaiju/status/1249272772963864576
# url,twitter.com/Max_Mal_/status/1514729699011928073
# url,twitter.com/MichalKoczwara/status/1377651431478595588
# url,twitter.com/MichalKoczwara/status/1385679642791665668
# url,twitter.com/MichalKoczwara/status/1424685098264301571
# url,twitter.com/StopMalvertisin/status/1533651010111307776
# url,twitter.com/TheDFIRReport/status/1376878123061551104
# url,twitter.com/TheDFIRReport/status/1463175512000368640
# url,twitter.com/Unit42_Intel/status/1387149833274810368
# url,twitter.com/Unit42_Intel/status/1437787000690683911
# url,twitter.com/Unit42_Intel/status/1440027013595766784
# url,twitter.com/Unit42_Intel/status/1463178309160906753
# url,twitter.com/Unit42_Intel/status/1470778363254128651
# url,twitter.com/Unit42_Intel/status/1492160514109149193
# url,twitter.com/Unit42_Intel/status/1498802280992227330?s=20&t=iDY6vP8NF3muXpkS4ERenw
# url,twitter.com/Unit42_Intel/status/1579876998276558862
# url,twitter.com/_brettfitz/status/1404095220506103812
# url,twitter.com/_brettfitz/status/1404438059962208256
# url,twitter.com/benkow_/status/1437376463305596929
# url,twitter.com/bryceabdo/status/1308743381099646976
# url,twitter.com/bryceabdo/status/1308778721797640195
# url,twitter.com/bryceabdo/status/1308802052487774210
# url,twitter.com/bryceabdo/status/1372895643102969861
# url,twitter.com/czy_1116/status/1485813878550597632
# url,twitter.com/fr0s7_/status/1458150977278726147
# url,twitter.com/h2jazi/status/1483504922003968003
# url,twitter.com/h2jazi/status/1544368077286039552
# url,twitter.com/h2jazi/status/1546501371725320193
# url,twitter.com/h2jazi/status/1546501374350868481
# url,twitter.com/kienbigmummy/status/1468836018560192512
# url,twitter.com/malware_traffic/status/1470812160427233294
# url,twitter.com/malwrhunterteam/status/1318904041590718469
# url,twitter.com/malwrhunterteam/status/1425771461499920385
# url,twitter.com/malwrhunterteam/status/1452992872928661512
# url,twitter.com/malwrhunterteam/status/1455885521905934339
# url,twitter.com/malwrhunterteam/status/1471915892980264962/
# url,twitter.com/malwrhunterteam/status/1476211484103524366
# url,twitter.com/mojoesec/status/1403072399860506638
# url,twitter.com/mojoesec/status/1418625292105654275
# url,twitter.com/mojoesec/status/1421198691742986243
# url,twitter.com/netresec/status/1506990534547709972
# url,twitter.com/obfusor/status/1539945037563174912
# url,twitter.com/z0ul_/status/1374724622508245008
# url,twitter.com/z0ul_/status/1377385770470703106
# url,unit42.paloaltonetworks.com/bumblebee-malware-projector-libra/
# url,unit42.paloaltonetworks.com/cobalt-strike-malleable-c2-profile/
# url,unit42.paloaltonetworks.com/solarstorm-supply-chain-attack-timeline
# url,www.blackarrow.net/leveraging-microsoft-teams-to-persist-and-cover-up-cobalt-strike-traffic/
# url,www.cert.ssi.gouv.fr/cti/CERTFR-2021-CTI-009
# url,www.cert.ssi.gouv.fr/uploads/CERTFR-2021-CTI-009.pdf
# url,www.cert.ssi.gouv.fr/uploads/CERTFR-2021-CTI-011.pdf
# url,www.clearskysec.com/wp-content/uploads/2017/07/Operation_Wilted_Tulip.pdf
# url,www.cobaltstrike.com/help-malleable-c2
# url,www.cynet.com/orion-threat-alert-flight-of-the-bumblebee/
# url,www.fireeye.com/blog/threat-research/2021/04/unc2447-sombrat-and-fivehands-ransomware-sophisticated-financial-threat.html
# url,www.malware-traffic-analysis.net/2021/09/20/index.html
# url,www.malware-traffic-analysis.net/2022/07/26/index.html
# url,www.mandiant.com/resources/fin12-ransomware-intrusion-actor-pursuing-healthcare-targets
# url,www.microsoft.com/security/blog/2021/05/27/new-sophisticated-email-based-attack-from-nobelium/
# url,www.microsoft.com/security/blog/2021/05/28/breaking-down-nobeliums-latest-early-stage-toolset/
# url,www.ptsecurity.com/ww-en/analytics/pt-esc-threat-intelligence/new-apt-group-chamelgang/
# url,www.recordedfuture.com/chinese-group-tag-22-targets-nepal-philippines-taiwan/
# url,www.sekoia.io/en/nobeliums-envyscout-infection-chain-goes-in-the-registry-targeting-embassies
# url,www.youtube.com/watch?v=BhjQ6zsCVSc
# url,www.youtube.com/watch?v=zAB5G-QOyx8

# %% [markdown]
# But note that many links might be dead.

# %%
RULES_PURPLE_FOX = DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE \
    .msg.str.contains("PurpleFox", re.IGNORECASE)] \
    .drop(columns=["metadata", "flowbits"]) \
    .explode("references") \
    .sort_values(by=["msg"]) \
    .drop(columns=["raw"])

# %%
RULES_PURPLE_FOX
# Out:
#       proto        src_net       dest_net      sid  rev  \
# 16297  http      $HOME_NET  $EXTERNAL_NET  2028978    3
# 16296  http      $HOME_NET  $EXTERNAL_NET  2028977    3
# 16113  http  $EXTERNAL_NET      $HOME_NET  2028974    2
# 16114  http  $EXTERNAL_NET      $HOME_NET  2028975    2
# 16295  http  $EXTERNAL_NET      $HOME_NET  2028976    3
# 16293  http  $EXTERNAL_NET      $HOME_NET  2028982    2
# 16298  http  $EXTERNAL_NET      $HOME_NET  2028981    3
# 16292  http      $HOME_NET  $EXTERNAL_NET  2028980    2
# 16334  http      $HOME_NET  $EXTERNAL_NET  2031466    2
# 16291  http      $HOME_NET  $EXTERNAL_NET  2028979    2
# 16332  http      $HOME_NET  $EXTERNAL_NET  2031462    2
# 16333  http  $EXTERNAL_NET      $HOME_NET  2031463    1
# 16336  http  $EXTERNAL_NET      $HOME_NET  2032480    1
# 16294  http      $HOME_NET  $EXTERNAL_NET  2028973    3
# 16331   dns      $HOME_NET            any  2031461    1
# 16337   dns      $HOME_NET            any  2032482    2
# 16395   tls      $HOME_NET  $EXTERNAL_NET  2032481    2
# 10954   dns      $HOME_NET            any  2035307    1
# 10954   dns      $HOME_NET            any  2035307    1
# 10753   tcp      $HOME_NET  $EXTERNAL_NET  2034873    1
# 10753   tcp      $HOME_NET  $EXTERNAL_NET  2034873    1
# 10750  http      $HOME_NET  $EXTERNAL_NET  2034859    2
# 10750  http      $HOME_NET  $EXTERNAL_NET  2034859    2
# 10752  http      $HOME_NET  $EXTERNAL_NET  2034871    1
# 10752  http      $HOME_NET  $EXTERNAL_NET  2034871    1
# 10751  http  $EXTERNAL_NET      $HOME_NET  2034856    2
# 10762  http  $EXTERNAL_NET      $HOME_NET  2034872    2
# 11336  http  $EXTERNAL_NET      $HOME_NET  2035621    2
# 11336  http  $EXTERNAL_NET      $HOME_NET  2035621    2
# 11337  http  $EXTERNAL_NET      $HOME_NET  2035622    1
# 11337  http  $EXTERNAL_NET      $HOME_NET  2035622    1
# 9667    tls      $HOME_NET  $EXTERNAL_NET  2032889    1
# 10962  http      $HOME_NET  $EXTERNAL_NET  2035313    1
# 10962  http      $HOME_NET  $EXTERNAL_NET  2035313    1
# 10962  http      $HOME_NET  $EXTERNAL_NET  2035313    1
# 10979   dns      $HOME_NET            any  2035384    1
# 10980  http      $HOME_NET  $EXTERNAL_NET  2035385    1
#
#                                                                                 msg  \
# 16297              ET EXPLOIT_KIT Possible PurpleFox EK Framework Flash GET Request
# 16296             ET EXPLOIT_KIT Possible PurpleFox EK Framework Flash HEAD Request
# 16113                        ET EXPLOIT_KIT Possible PurpleFox EK Framework Landing
# 16114     ET EXPLOIT_KIT Possible PurpleFox EK Framework Landing - Various Exploits
# 16295                        ET EXPLOIT_KIT Possible PurpleFox EK Framework Payload
# 16293                        ET EXPLOIT_KIT Possible PurpleFox EK Framework Payload
# 16298                        ET EXPLOIT_KIT Possible PurpleFox EK Framework Payload
# 16292       ET EXPLOIT_KIT Possible PurpleFox EK Framework URI Struct Flash Request
# 16334         ET EXPLOIT_KIT Possible PurpleFox EK Framework URI Struct Jpg Request
# 16291     ET EXPLOIT_KIT Possible PurpleFox EK Framework URI Struct Landing Request
# 16332  ET EXPLOIT_KIT Possible PurpleFox EK Framework URI Struct Payload Request M1
# 16333                                 ET EXPLOIT_KIT Possible PurpleFox EK Redirect
# 16336                              ET EXPLOIT_KIT Possible PurpleFox EK Redirect M2
# 16294                     ET EXPLOIT_KIT Possible PurpleFox/RIG EK Flash Request M2
# 16331                              ET EXPLOIT_KIT PurpleFox EK Domain in DNS Lookup
# 16337         ET EXPLOIT_KIT Suspicious GitHack DNS Request - Possible PurpleFox EK
# 16395     ET EXPLOIT_KIT Suspicious GitHack TLS SNI Request - Possible PurpleFox EK
# 10954     ET MALWARE PurpleFox Backdoor Related Domain in DNS Lookup (qq .c1c .ren)
# 10954     ET MALWARE PurpleFox Backdoor Related Domain in DNS Lookup (qq .c1c .ren)
# 10753                                 ET MALWARE PurpleFox Backdoor/Rootkit Checkin
# 10753                                 ET MALWARE PurpleFox Backdoor/Rootkit Checkin
# 10750                     ET MALWARE PurpleFox Backdoor/Rootkit Download Request M1
# 10750                     ET MALWARE PurpleFox Backdoor/Rootkit Download Request M1
# 10752                     ET MALWARE PurpleFox Backdoor/Rootkit Download Request M2
# 10752                     ET MALWARE PurpleFox Backdoor/Rootkit Download Request M2
# 10751             ET MALWARE PurpleFox Backdoor/Rootkit Download Server Response M1
# 10762             ET MALWARE PurpleFox Backdoor/Rootkit Download Server Response M2
# 11336             ET MALWARE PurpleFox Backdoor/Rootkit Download Server Response M3
# 11336             ET MALWARE PurpleFox Backdoor/Rootkit Download Server Response M3
# 11337             ET MALWARE PurpleFox Backdoor/Rootkit Download Server Response M4
# 11337             ET MALWARE PurpleFox Backdoor/Rootkit Download Server Response M4
# 9667                             ET MALWARE PurpleFox EK Landing Page Domain in SNI
# 10962                             ET MALWARE Win32/PurpleFox Related Activity (GET)
# 10962                             ET MALWARE Win32/PurpleFox Related Activity (GET)
# 10962                             ET MALWARE Win32/PurpleFox Related Activity (GET)
# 10979                       ET MALWARE Win32/PurpleFox Related Domain in DNS Lookup
# 10980                              ET MALWARE Win32/PurpleFox Retrieving File (GET)
#
#                              file  \
# 16297  emerging-exploit_kit.rules
# 16296  emerging-exploit_kit.rules
# 16113  emerging-exploit_kit.rules
# 16114  emerging-exploit_kit.rules
# 16295  emerging-exploit_kit.rules
# 16293  emerging-exploit_kit.rules
# 16298  emerging-exploit_kit.rules
# 16292  emerging-exploit_kit.rules
# 16334  emerging-exploit_kit.rules
# 16291  emerging-exploit_kit.rules
# 16332  emerging-exploit_kit.rules
# 16333  emerging-exploit_kit.rules
# 16336  emerging-exploit_kit.rules
# 16294  emerging-exploit_kit.rules
# 16331  emerging-exploit_kit.rules
# 16337  emerging-exploit_kit.rules
# 16395  emerging-exploit_kit.rules
# 10954      emerging-malware.rules
# 10954      emerging-malware.rules
# 10753      emerging-malware.rules
# 10753      emerging-malware.rules
# 10750      emerging-malware.rules
# 10750      emerging-malware.rules
# 10752      emerging-malware.rules
# 10752      emerging-malware.rules
# 10751      emerging-malware.rules
# 10762      emerging-malware.rules
# 11336      emerging-malware.rules
# 11336      emerging-malware.rules
# 11337      emerging-malware.rules
# 11337      emerging-malware.rules
# 9667       emerging-malware.rules
# 10962      emerging-malware.rules
# 10962      emerging-malware.rules
# 10962      emerging-malware.rules
# 10979      emerging-malware.rules
# 10980      emerging-malware.rules
#
#                                                                                                             references  \
# 16297                                                                                                              NaN
# 16296                                                                                                              NaN
# 16113                                                                                                              NaN
# 16114                                                                                                              NaN
# 16295                                                                                                              NaN
# 16293                                                                                                              NaN
# 16298                                                                                                              NaN
# 16292                                                                                                              NaN
# 16334                                                                                                              NaN
# 16291                                                                                                              NaN
# 16332                                                               url,twitter.com/nao_sec/status/1343918070989877252
# 16333                                                               url,twitter.com/nao_sec/status/1343918070989877252
# 16336                                                               url,twitter.com/nao_sec/status/1378546891349106692
# 16294                                                                                                              NaN
# 16331                                                               url,twitter.com/nao_sec/status/1343918070989877252
# 16337                                                                                                              NaN
# 16395                                                                                                              NaN
# 10954                                                                  url,twitter.com/0xrb/status/1496747426505531398
# 10954                                                                             md5,757e04a9da1083b797b9dadc94300937
# 10753                                                                             md5,465dae978a41d566c7fabc9f5808487c
# 10753                                  url,blog.minerva-labs.com/malicious-telegram-installer-drops-purple-fox-rootkit
# 10750                                                                             md5,c398b504f74500d6a1a47f72bb45bc83
# 10750                                  url,blog.minerva-labs.com/malicious-telegram-installer-drops-purple-fox-rootkit
# 10752                                                                             md5,465dae978a41d566c7fabc9f5808487c
# 10752                                  url,blog.minerva-labs.com/malicious-telegram-installer-drops-purple-fox-rootkit
# 10751                                  url,blog.minerva-labs.com/malicious-telegram-installer-drops-purple-fox-rootkit
# 10762                                  url,blog.minerva-labs.com/malicious-telegram-installer-drops-purple-fox-rootkit
# 11336  url,www.trendmicro.com/en_us/research/22/c/purple-fox-uses-new-arrival-vector-and-improves-malware-arsenal.html
# 11336                                                                             md5,930d405c7653dcf36c04e75224a2ff9d
# 11337                                                                             md5,930d405c7653dcf36c04e75224a2ff9d
# 11337  url,www.trendmicro.com/en_us/research/22/c/purple-fox-uses-new-arrival-vector-and-improves-malware-arsenal.html
# 9667                                                                                                               NaN
# 10962                                                              url,twitter.com/Max_Mal_/status/1498351091066589184
# 10962                                                                             md5,c793425d192af8f89b1b8c7e1ea6f792
# 10962                                                                             md5,7f757563585debbbccc3e34664de04fe
# 10979                                                                             md5,57b8bccf9cb8592ae86b4453cf74b4e8
# 10980                                                                             md5,57b8bccf9cb8592ae86b4453cf74b4e8
#
#                         flow
# 16297  established,to_server
# 16296  established,to_server
# 16113  established,to_client
# 16114  established,to_client
# 16295  established,to_client
# 16293  established,to_client
# 16298  established,to_client
# 16292  established,to_server
# 16334  established,to_server
# 16291  established,to_server
# 16332  established,to_server
# 16333  established,to_client
# 16336  established,to_client
# 16294  established,to_server
# 16331                    NaN
# 16337  established,to_server
# 16395  established,to_server
# 10954                    NaN
# 10954                    NaN
# 10753  established,to_server
# 10753  established,to_server
# 10750  established,to_server
# 10750  established,to_server
# 10752  established,to_server
# 10752  established,to_server
# 10751  established,to_client
# 10762  established,to_client
# 11336  established,to_client
# 11336  established,to_client
# 11337  established,to_client
# 11337  established,to_client
# 9667   to_server,established
# 10962  established,to_server
# 10962  established,to_server
# 10962  established,to_server
# 10979                    NaN
# 10980  established,to_server

# %%
RULES_EMOTET = DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE \
    .msg.str.contains("Emotet", re.IGNORECASE)] \
    .drop(columns=["metadata", "flowbits"]) \
    .explode("references") \
    .sort_values(by=["msg"]) \
    .drop(columns=["raw"])

# %%
RULES_EMOTET
# Out:
#       proto        src_net       dest_net      sid  rev  \
# 6031    tls  $EXTERNAL_NET      $HOME_NET  2035063    2
# 5106   http      $HOME_NET  $EXTERNAL_NET  2019693    6
# 9234   http      $HOME_NET  $EXTERNAL_NET  2035075    6
# 7969   http      $HOME_NET  $EXTERNAL_NET  2019704    4
# 3368   http  $EXTERNAL_NET      $HOME_NET  2035042    2
# 8943   http  $EXTERNAL_NET      $HOME_NET  2035049    4
# 4246   http      $HOME_NET  $EXTERNAL_NET  2029398    2
# 5186   http      $HOME_NET  $EXTERNAL_NET  2020900    4
# 6185   http      $HOME_NET  $EXTERNAL_NET  2035060    3
# 6046    tls  $EXTERNAL_NET      $HOME_NET  2035051    3
# 5159   http      $HOME_NET  $EXTERNAL_NET  2035045    5
# 4881   http      $HOME_NET  $EXTERNAL_NET  2018224    5
# 11215  http      $HOME_NET  $EXTERNAL_NET  2035043    4
# 5124   http      $HOME_NET  $EXTERNAL_NET  2035044    4
# 10841  http      $HOME_NET  $EXTERNAL_NET  2035064    2
# 2369    udp            any      $HOME_NET  2019692    1
# 10826  http  $EXTERNAL_NET      $HOME_NET  2035000    2
# 8857   http      $HOME_NET  $EXTERNAL_NET  2024272    6
# 10857  http  $EXTERNAL_NET      $HOME_NET  2035062    4
# 8856   http      $HOME_NET  $EXTERNAL_NET  2024274    4
# 8856   http      $HOME_NET  $EXTERNAL_NET  2024274    4
# 8856   http      $HOME_NET  $EXTERNAL_NET  2024274    4
# 8856   http      $HOME_NET  $EXTERNAL_NET  2024274    4
# 10586  http      $HOME_NET  $EXTERNAL_NET  2034459    1
# 6138   http      $HOME_NET  $EXTERNAL_NET  2035052    9
# 8893   http      $HOME_NET  $EXTERNAL_NET  2035046    4
# 6216   http      $HOME_NET  $EXTERNAL_NET  2035047    7
# 6982   http      $HOME_NET  $EXTERNAL_NET  2035055    6
# 6511   http      $HOME_NET  $EXTERNAL_NET  2030868    2
# 8316   http      $HOME_NET  $EXTERNAL_NET  2035077    1
# 6981   http      $HOME_NET  $EXTERNAL_NET  2035056    6
# 6983   http      $HOME_NET  $EXTERNAL_NET  2035058    4
# 6984   http      $HOME_NET  $EXTERNAL_NET  2035059    4
# 9166   http      $HOME_NET  $EXTERNAL_NET  2029059    3
# 9040   http      $HOME_NET  $EXTERNAL_NET  2029060    3
# 8628   http      $HOME_NET  $EXTERNAL_NET  2029279    2
# 11261  http      $HOME_NET  $EXTERNAL_NET  2029380    6
# 9352   http      $HOME_NET  $EXTERNAL_NET  2035076    8
# 6057   http      $HOME_NET  $EXTERNAL_NET  2035053    4
# 6166   http  $EXTERNAL_NET      $HOME_NET  2035054    4
# 6166   http  $EXTERNAL_NET      $HOME_NET  2035054    4
# 10770  http  $EXTERNAL_NET      $HOME_NET  2034882    1
# 5079   http      $HOME_NET  $EXTERNAL_NET  2020156    8
#
#                                                            msg  \
# 6031                 ET MALWARE Emotet Certificate Observed M2
# 5106                                 ET MALWARE Emotet Checkin
# 9234                              ET MALWARE Emotet CnC Beacon
# 7969                              ET MALWARE Emotet CnC Beacon
# 3368                      ET MALWARE Emotet Post Drop C2 Comms
# 8943                   ET MALWARE Emotet Post Drop C2 Comms M2
# 4246              ET MALWARE Emotet Wifi Bruter Module Checkin
# 5186     ET MALWARE Emotet v2 Exfiltrating Outlook information
# 6185             ET MALWARE Evil PDF Retrieving Emotet Payload
# 6046          ET MALWARE IcedID/Emotet Certificate Observed M1
# 5159                 ET MALWARE Likely Geodo/Emotet CnC Beacon
# 4881             ET MALWARE Likely Geodo/Emotet Downloading PE
# 11215            ET MALWARE Likely Geodo/Emotet Downloading PE
# 5124   ET MALWARE Likely Geodo/Emotet Downloading PE - Fake UA
# 10841  ET MALWARE Office Macro Emotet Download URI Nov 24 2021
# 2369         ET MALWARE Possible Emotet DGA NXDOMAIN Responses
# 10826      ET MALWARE PowerShell Script Downloading Emotet DLL
# 8857                       ET MALWARE W32.Geodo/Emotet Checkin
# 10857    ET MALWARE W32.Geodo/Emotet Checkin Fake 404 Response
# 8856                        ET MALWARE W32/Emotet CnC Beacon 1
# 8856                        ET MALWARE W32/Emotet CnC Beacon 1
# 8856                        ET MALWARE W32/Emotet CnC Beacon 1
# 8856                        ET MALWARE W32/Emotet CnC Beacon 1
# 10586                       ET MALWARE W32/Emotet CnC Beacon 3
# 6138                         ET MALWARE W32/Emotet CnC Checkin
# 8893                    ET MALWARE W32/Emotet Empty CnC Beacon
# 6216                          ET MALWARE W32/Emotet.v4 Checkin
# 6982               ET MALWARE Win32/Emotet CnC Activity (POST)
# 6511           ET MALWARE Win32/Emotet CnC Activity (POST) M10
# 8316           ET MALWARE Win32/Emotet CnC Activity (POST) M11
# 6981            ET MALWARE Win32/Emotet CnC Activity (POST) M2
# 6983            ET MALWARE Win32/Emotet CnC Activity (POST) M3
# 6984            ET MALWARE Win32/Emotet CnC Activity (POST) M4
# 9166            ET MALWARE Win32/Emotet CnC Activity (POST) M5
# 9040            ET MALWARE Win32/Emotet CnC Activity (POST) M6
# 8628            ET MALWARE Win32/Emotet CnC Activity (POST) M7
# 11261           ET MALWARE Win32/Emotet CnC Activity (POST) M8
# 9352            ET MALWARE Win32/Emotet CnC Activity (POST) M9
# 6057                ET MALWARE Win32/Emotet CnC Checkin (POST)
# 6166              ET MALWARE Win32/Emotet CnC Checkin Response
# 6166              ET MALWARE Win32/Emotet CnC Checkin Response
# 10770           ET MALWARE Win32/Emotet HTML Template Response
# 5079                         ET MALWARE Win32/Emotet.C Checkin
#
#                          file  \
# 6031   emerging-malware.rules
# 5106   emerging-malware.rules
# 9234   emerging-malware.rules
# 7969   emerging-malware.rules
# 3368   emerging-malware.rules
# 8943   emerging-malware.rules
# 4246   emerging-malware.rules
# 5186   emerging-malware.rules
# 6185   emerging-malware.rules
# 6046   emerging-malware.rules
# 5159   emerging-malware.rules
# 4881   emerging-malware.rules
# 11215  emerging-malware.rules
# 5124   emerging-malware.rules
# 10841  emerging-malware.rules
# 2369   emerging-malware.rules
# 10826  emerging-malware.rules
# 8857   emerging-malware.rules
# 10857  emerging-malware.rules
# 8856   emerging-malware.rules
# 8856   emerging-malware.rules
# 8856   emerging-malware.rules
# 8856   emerging-malware.rules
# 10586  emerging-malware.rules
# 6138   emerging-malware.rules
# 8893   emerging-malware.rules
# 6216   emerging-malware.rules
# 6982   emerging-malware.rules
# 6511   emerging-malware.rules
# 8316   emerging-malware.rules
# 6981   emerging-malware.rules
# 6983   emerging-malware.rules
# 6984   emerging-malware.rules
# 9166   emerging-malware.rules
# 9040   emerging-malware.rules
# 8628   emerging-malware.rules
# 11261  emerging-malware.rules
# 9352   emerging-malware.rules
# 6057   emerging-malware.rules
# 6166   emerging-malware.rules
# 6166   emerging-malware.rules
# 10770  emerging-malware.rules
# 5079   emerging-malware.rules
#
#                                                                                       references  \
# 6031                                                        md5,8430d8cf1b1edd6c49092a7dd6412a8a
# 5106                                                        md5,3083b68cb5c2a345972a5f79e735c7b9
# 9234                                                        md5,518d189f8922280c81ab123604076dfd
# 7969                                                        md5,e24831e3f808116b30d85731c545e3ee
# 3368                                                                                         NaN
# 8943                                                        md5,dacdcd451204265ad6f44ef99db1f371
# 4246                            url,www.binarydefense.com/emotet-evolves-with-new-wi-fi-spreader
# 5186              url,securelist.com/analysis/69560/the-banking-trojan-emotet-detailed-analysis/
# 6185                                                        md5,136dca58d0a0802c7abfce8dce4b7526
# 6046                                                        md5,8430d8cf1b1edd6c49092a7dd6412a8a
# 5159                                                        md5,6c4d198794d1afd2b8bbae6f16bdfaa7
# 4881                                                                                         NaN
# 11215                                                       md5,6c4d198794d1afd2b8bbae6f16bdfaa7
# 5124                                                        md5,6c4d198794d1afd2b8bbae6f16bdfaa7
# 10841                                                       md5,67ec9f81dd3970e3e5f66121a3502b5d
# 2369                                                        md5,3083b68cb5c2a345972a5f79e735c7b9
# 10826                                                       md5,c3cb504f97c7c7df9c25b0957dd60d9f
# 8857                                                        md5,dacdcd451204265ad6f44ef99db1f371
# 10857                                                       md5,dacdcd451204265ad6f44ef99db1f371
# 8856                                            url,www.cyphort.com/emotet-cookies-c2-fakes-404/
# 8856   url,blogs.forcepoint.com/security-labs/new-variant-geodoemotet-banking-malware-targets-uk
# 8856                 url,blog.fortinet.com/2017/05/03/deep-analysis-of-new-emotet-variant-part-1
# 8856                                                        md5,21542133a586782e7c2fa4286d98fd73
# 10586                                                       md5,bc3532085a0b4febd9eed51aac2180d0
# 6138                                                        md5,d51ce75c66d1ac9f071b45b67fb8066c
# 8893                                                        md5,627f3572e9c37de307b3511925934fb9
# 6216                                                                                         NaN
# 6982                                                        md5,4ca520895d86beb6f8cab93639f26f50
# 6511                                                        md5,ba2e4a231652f8a492feb937b1e96e71
# 8316                                                        md5,f4b00ffce71b197865071073dec5068d
# 6981                                                        md5,156e021f890dd6eb6f271c2ad9b0316e
# 6983                                                        md5,bda5b754bb079eec4389a9f43d16c903
# 6984                                                        md5,bda5b754bb079eec4389a9f43d16c903
# 9166                                                        md5,e5fecd3be1747f6a934f70e921399a10
# 9040                                                        md5,e5fecd3be1747f6a934f70e921399a10
# 8628                                                                                         NaN
# 11261                                                                                        NaN
# 9352                                                        md5,73f8864c7dfee8445205d0d233f20707
# 6057                                                                                         NaN
# 6166                                                        md5,4ca520895d86beb6f8cab93639f26f50
# 6166                                                        md5,129ed9c08c8ba6dc62d48ff2c3fc6a50
# 10770                                                                                        NaN
# 5079                                                        md5,37d530ffa0bf1129f2db63b75fccce28
#
#                           flow
# 6031     established,to_client
# 5106     established,to_server
# 9234     established,to_server
# 7969     established,to_server
# 3368   established,from_server
# 8943   established,from_server
# 4246     established,to_server
# 5186     established,to_server
# 6185     established,to_server
# 6046     established,to_client
# 5159     established,to_server
# 4881     established,to_server
# 11215    established,to_server
# 5124     established,to_server
# 10841    established,to_server
# 2369                       NaN
# 10826  from_server,established
# 8857     established,to_server
# 10857  established,from_server
# 8856     established,to_server
# 8856     established,to_server
# 8856     established,to_server
# 8856     established,to_server
# 10586    established,to_server
# 6138     established,to_server
# 8893     established,to_server
# 6216     established,to_server
# 6982     established,to_server
# 6511     established,to_server
# 8316     established,to_server
# 6981     established,to_server
# 6983     established,to_server
# 6984     established,to_server
# 9166     established,to_server
# 9040     established,to_server
# 8628     established,to_server
# 11261    established,to_server
# 9352     established,to_server
# 6057     established,to_server
# 6166     established,to_client
# 6166     established,to_client
# 10770    established,to_client
# 5079     to_server,established

# %% [markdown]
# ## Interactive widgets
#
# * https://ipywidgets.readthedocs.io/en/latest/
#
# Not all data exploration must be done with pure code any more. Widgets are a great way to expose any data user is interested in.

# %%
! pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /home/vagrant/.venv/lib/python3.8/site-packages (8.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipywidgets) (4.0.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipywidgets) (3.0.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipywidgets) (6.16.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipywidgets) (8.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: psutil in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.2)
# Requirement already satisfied: tornado>=6.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: packaging in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.2)
# Requirement already satisfied: nest-asyncio in /home/vagrant/.venv/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.31)
# Requirement already satisfied: decorator in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: stack-data in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/vagrant/.venv/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/vagrant/.venv/lib/python3.8/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vagrant/.venv/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/vagrant/.venv/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.11.1)
# Requirement already satisfied: entrypoints in /home/vagrant/.venv/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: wcwidth in /home/vagrant/.venv/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vagrant/.venv/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: asttokens in /home/vagrant/.venv/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.8)
# Requirement already satisfied: executing in /home/vagrant/.venv/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: pure-eval in /home/vagrant/.venv/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/vagrant/.venv/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: six>=1.5 in /home/vagrant/.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)

# %%
import re

# %%
def show_rules(limit: int, msg: str, columns: tuple, sort: tuple):
    pd.set_option('display.max_rows', limit)
    pd.set_option('display.min_rows', limit)
    return (
        DF_ET_OPEN_ALL[list(columns)]
        .loc[DF_ET_OPEN_ALL.msg.str.contains(msg, flags=re.IGNORECASE)]
        .sort_values(by=[c for c in list(sort) if c in list(columns)])
    )

# %%
import ipywidgets as widgets

# %%
widgets.interact(
    show_rules, 
    msg="", 
    limit=widgets.IntSlider(min=10, max=100),
    columns=widgets.SelectMultiple(
        options=list(DF_ET_OPEN_ALL.columns.values),
        value=CORE_COLS
    ),
    sort=widgets.SelectMultiple(
        options=list(DF_ET_OPEN_ALL.columns.values),
    )
)
# Out:
# interactive(children=(IntSlider(value=10, description='limit', min=10), Text(value='', description='msg'), Sel…
# <function __main__.show_rules(limit: int, msg: str, columns: tuple, sort: tuple)>
