# %% [markdown]
# As preface, let's import some libraries we need to use.
#
# `python3 -m pip install --user pandas numpy idstools`

# %%
import pandas as pd
import numpy as np

from idstools import rule

import glob
import json
import os
import re

# %% [markdown]
# # ET Open
#
# Download ET Open ruleset.
# ```
# wget https://rules.emergingthreats.net/open/suricata-6.0.1/emerging.rules.tar.gz
# ```
#
# And unpack.
#
# ```
# mkdir /tmp/etopen
# tar -xzf emerging.rules.tar.gz -C /tmp/etopen
# ```
#
# Note that this folder in `tmp` must be synced with following `glob` code which constructs a python list of all rule files.

# %%
RULES_LIST_ET_OPEN = glob.glob("/tmp/etopen/rules/*.rules")

# %% [markdown]
# Then use python code to get a organized list of rule files.

# %%
sorted(RULES_LIST_ET_OPEN)
# Out:
# ['/tmp/etopen/rules/3coresec.rules',
#  '/tmp/etopen/rules/botcc.portgrouped.rules',
#  '/tmp/etopen/rules/botcc.rules',
#  '/tmp/etopen/rules/ciarmy.rules',
#  '/tmp/etopen/rules/compromised.rules',
#  '/tmp/etopen/rules/drop.rules',
#  '/tmp/etopen/rules/dshield.rules',
#  '/tmp/etopen/rules/emerging-activex.rules',
#  '/tmp/etopen/rules/emerging-adware_pup.rules',
#  '/tmp/etopen/rules/emerging-attack_response.rules',
#  '/tmp/etopen/rules/emerging-chat.rules',
#  '/tmp/etopen/rules/emerging-coinminer.rules',
#  '/tmp/etopen/rules/emerging-current_events.rules',
#  '/tmp/etopen/rules/emerging-deleted.rules',
#  '/tmp/etopen/rules/emerging-dns.rules',
#  '/tmp/etopen/rules/emerging-dos.rules',
#  '/tmp/etopen/rules/emerging-exploit.rules',
#  '/tmp/etopen/rules/emerging-exploit_kit.rules',
#  '/tmp/etopen/rules/emerging-ftp.rules',
#  '/tmp/etopen/rules/emerging-games.rules',
#  '/tmp/etopen/rules/emerging-hunting.rules',
#  '/tmp/etopen/rules/emerging-icmp.rules',
#  '/tmp/etopen/rules/emerging-icmp_info.rules',
#  '/tmp/etopen/rules/emerging-imap.rules',
#  '/tmp/etopen/rules/emerging-inappropriate.rules',
#  '/tmp/etopen/rules/emerging-info.rules',
#  '/tmp/etopen/rules/emerging-ja3.rules',
#  '/tmp/etopen/rules/emerging-malware.rules',
#  '/tmp/etopen/rules/emerging-misc.rules',
#  '/tmp/etopen/rules/emerging-mobile_malware.rules',
#  '/tmp/etopen/rules/emerging-netbios.rules',
#  '/tmp/etopen/rules/emerging-p2p.rules',
#  '/tmp/etopen/rules/emerging-phishing.rules',
#  '/tmp/etopen/rules/emerging-policy.rules',
#  '/tmp/etopen/rules/emerging-pop3.rules',
#  '/tmp/etopen/rules/emerging-rpc.rules',
#  '/tmp/etopen/rules/emerging-scada.rules',
#  '/tmp/etopen/rules/emerging-scan.rules',
#  '/tmp/etopen/rules/emerging-shellcode.rules',
#  '/tmp/etopen/rules/emerging-smtp.rules',
#  '/tmp/etopen/rules/emerging-snmp.rules',
#  '/tmp/etopen/rules/emerging-sql.rules',
#  '/tmp/etopen/rules/emerging-telnet.rules',
#  '/tmp/etopen/rules/emerging-tftp.rules',
#  '/tmp/etopen/rules/emerging-user_agents.rules',
#  '/tmp/etopen/rules/emerging-voip.rules',
#  '/tmp/etopen/rules/emerging-web_client.rules',
#  '/tmp/etopen/rules/emerging-web_server.rules',
#  '/tmp/etopen/rules/emerging-web_specific_apps.rules',
#  '/tmp/etopen/rules/emerging-worm.rules',
#  '/tmp/etopen/rules/tor.rules']

# %% [markdown]
# And parse each rule file with `idstools`, and construct a python dictionary where keys are rule files and values are list of parsed rules.

# %%
# %time PARSED_ET_OPEN = {k: rule.parse_file(k) for k in RULES_LIST_ET_OPEN}
# Out:
# CPU times: user 1.78 s, sys: 163 ms, total: 1.94 s
# Wall time: 1.98 s

# %% [markdown]
# Consider the following parsed rule. Notice how much information can be extracted from it. And reader should already be familiar with sequential option list.

# %%
print(
    json.dumps(
        PARSED_ET_OPEN["/tmp/etopen/rules/emerging-malware.rules"][0], 
        indent=2
    )
)
# Out:
# {
#   "enabled": false,
#   "action": "alert",
#   "direction": "->",
#   "group": null,
#   "gid": 1,
#   "sid": 2009172,
#   "rev": 2,
#   "msg": "ET MALWARE Psyb0t joining an IRC Channel",
#   "flowbits": [
#     "isset,is_proto_irc"
#   ],
#   "metadata": [
#     "created_at 2010_07_30",
#     "updated_at 2010_07_30"
#   ],
#   "references": [
#     "url,www.adam.com.au/bogaurd/PSYB0T.pdf",
#     "url,doc.emergingthreats.net/2009172"
#   ],
#   "classtype": "trojan-activity",
#   "priority": 0,
#   "options": [
#     {
#       "name": "msg",
#       "value": "\"ET MALWARE Psyb0t joining an IRC Channel\""
#     },
#     {
#       "name": "flow",
#       "value": "established,to_server"
#     },
#     {
#       "name": "flowbits",
#       "value": "isset,is_proto_irc"
#     },
#     {
#       "name": "content",
#       "value": "\"JOIN #mipsel\""
#     },
#     {
#       "name": "reference",
#       "value": "url,www.adam.com.au/bogaurd/PSYB0T.pdf"
#     },
#     {
#       "name": "reference",
#       "value": "url,doc.emergingthreats.net/2009172"
#     },
#     {
#       "name": "classtype",
#       "value": "trojan-activity"
#     },
#     {
#       "name": "sid",
#       "value": "2009172"
#     },
#     {
#       "name": "rev",
#       "value": "2"
#     },
#     {
#       "name": "metadata",
#       "value": "created_at 2010_07_30, updated_at 2010_07_30"
#     }
#   ],
#   "raw": "alert tcp $HOME_NET any -> $EXTERNAL_NET any (msg:\"ET MALWARE Psyb0t joining an IRC Channel\"; flow:established,to_server; flowbits:isset,is_proto_irc; content:\"JOIN #mipsel\"; reference:url,www.adam.com.au/bogaurd/PSYB0T.pdf; reference:url,doc.emergingthreats.net/2009172; classtype:trojan-activity; sid:2009172; rev:2; metadata:created_at 2010_07_30, updated_at 2010_07_30;)",
#   "header": "alert tcp $HOME_NET any -> $EXTERNAL_NET any",
#   "flow": "established,to_server",
#   "content": "\"JOIN #mipsel\""
# }

# %% [markdown]
# ## High level view

# %% [markdown]
# Traditional data structures can be difficult for human eyes to grasp. On small scale they are fine, but things become complex if you consider that ET Open contains over 31 **thousand** rules. However, aggregations presented in row-column format can help us out here.
#
# For that, we can use `pandas` scientific package which implements **data frames** in python. Great for data wrangling and exploration. Following block creates a new pandas data frame, and initializes columns of counters per rule file. For now, we're just interested in `total number of rules`, `number of enabled rules` and `number of disabled rules`.

# %%
DF_HIGH_LEVEL = pd.DataFrame()
DF_HIGH_LEVEL["file"] = list(PARSED_ET_OPEN.keys())
DF_HIGH_LEVEL["rules_total_count"] = list([len(v) for v in PARSED_ET_OPEN.values()])
DF_HIGH_LEVEL["rules_disabled_count"] = list([len([item for item in v if not item.enabled]) for v in PARSED_ET_OPEN.values()])
DF_HIGH_LEVEL["rules_enabled_count"] = list([len([item for item in v if item.enabled]) for v in PARSED_ET_OPEN.values()])

# %% [markdown]
# Then present the dataframe sorted by the number of active rules per file.

# %%
DF_HIGH_LEVEL.sort_values(by=["rules_enabled_count"], ascending=False)
# Out:
#                                                  file  rules_total_count  \
# 2            /tmp/etopen/rules/emerging-malware.rules               8830
# 15  /tmp/etopen/rules/emerging-web_specific_apps.r...               5577
# 46                        /tmp/etopen/rules/tor.rules               1063
# 0           /tmp/etopen/rules/emerging-phishing.rules               1020
# 9            /tmp/etopen/rules/emerging-exploit.rules               1094
# 41            /tmp/etopen/rules/emerging-policy.rules               1092
# 42        /tmp/etopen/rules/emerging-web_server.rules                711
# 50    /tmp/etopen/rules/emerging-mobile_malware.rules                679
# 12              /tmp/etopen/rules/emerging-info.rules                622
# 4         /tmp/etopen/rules/emerging-adware_pup.rules               1117
# 34        /tmp/etopen/rules/emerging-web_client.rules                785
# 38       /tmp/etopen/rules/emerging-exploit_kit.rules               1314
# 21           /tmp/etopen/rules/emerging-netbios.rules                474
# 33           /tmp/etopen/rules/emerging-hunting.rules                366
# 18              /tmp/etopen/rules/emerging-scan.rules                341
# 5        /tmp/etopen/rules/emerging-user_agents.rules                283
# 25                /tmp/etopen/rules/compromised.rules                219
# 27               /tmp/etopen/rules/emerging-sql.rules                311
# 1            /tmp/etopen/rules/emerging-activex.rules                533
# 8                /tmp/etopen/rules/emerging-ja3.rules                125
# 36   /tmp/etopen/rules/emerging-attack_response.rules                218
# 6                      /tmp/etopen/rules/ciarmy.rules                100
# 29               /tmp/etopen/rules/emerging-p2p.rules                119
# 23               /tmp/etopen/rules/emerging-rpc.rules                117
# 44              /tmp/etopen/rules/emerging-chat.rules                 90
# 14               /tmp/etopen/rules/emerging-dos.rules                111
# 28         /tmp/etopen/rules/emerging-shellcode.rules                186
# 7                /tmp/etopen/rules/emerging-ftp.rules                115
# 49                      /tmp/etopen/rules/botcc.rules                 55
# 43    /tmp/etopen/rules/emerging-current_events.rules                189
# 37                       /tmp/etopen/rules/drop.rules                 39
# 16               /tmp/etopen/rules/emerging-dns.rules                 49
# 31              /tmp/etopen/rules/emerging-misc.rules                 62
# 35         /tmp/etopen/rules/emerging-coinminer.rules                 22
# 24                   /tmp/etopen/rules/3coresec.rules                 20
# 40             /tmp/etopen/rules/emerging-scada.rules                 18
# 48          /tmp/etopen/rules/botcc.portgrouped.rules                 18
# 17              /tmp/etopen/rules/emerging-imap.rules                 33
# 20              /tmp/etopen/rules/emerging-snmp.rules                 33
# 13              /tmp/etopen/rules/emerging-voip.rules                 21
# 26              /tmp/etopen/rules/emerging-smtp.rules                 23
# 11         /tmp/etopen/rules/emerging-icmp_info.rules                 66
# 45              /tmp/etopen/rules/emerging-tftp.rules                 20
# 3              /tmp/etopen/rules/emerging-games.rules                 77
# 30              /tmp/etopen/rules/emerging-worm.rules                 19
# 39              /tmp/etopen/rules/emerging-pop3.rules                 20
# 22            /tmp/etopen/rules/emerging-telnet.rules                 10
# 19     /tmp/etopen/rules/emerging-inappropriate.rules                 25
# 47                    /tmp/etopen/rules/dshield.rules                  1
# 32              /tmp/etopen/rules/emerging-icmp.rules                 39
# 10           /tmp/etopen/rules/emerging-deleted.rules               3095
#
#     rules_disabled_count  rules_enabled_count
# 2                   2454                 6376
# 15                   748                 4829
# 46                     0                 1063
# 0                    100                  920
# 9                    292                  802
# 41                   324                  768
# 42                   106                  605
# 50                    76                  603
# 12                    45                  577
# 4                    584                  533
# 34                   285                  500
# 38                   895                  419
# 21                    82                  392
# 33                    58                  308
# 18                    73                  268
# 5                     50                  233
# 25                     0                  219
# 27                   120                  191
# 1                    347                  186
# 8                      2                  123
# 36                    98                  120
# 6                      0                  100
# 29                    31                   88
# 23                    34                   83
# 44                    20                   70
# 14                    45                   66
# 28                   124                   62
# 7                     58                   57
# 49                     0                   55
# 43                   147                   42
# 37                     0                   39
# 16                    17                   32
# 31                    40                   22
# 35                     2                   20
# 24                     0                   20
# 40                     0                   18
# 48                     0                   18
# 17                    16                   17
# 20                    17                   16
# 13                     5                   16
# 26                     9                   14
# 11                    52                   14
# 45                     7                   13
# 3                     66                   11
# 30                    10                    9
# 39                    11                    9
# 22                     2                    8
# 19                    24                    1
# 47                     0                    1
# 32                    39                    0
# 10                  3095                    0

# %% [markdown]
# Each column of counters is a vector that can be summed up for total counts.

# %%
print("Enabled: {} Disabled: {} Total: {}".format(
    DF_HIGH_LEVEL.rules_enabled_count.sum(),
    DF_HIGH_LEVEL.rules_disabled_count.sum(),
    DF_HIGH_LEVEL.rules_total_count.sum(),
))
# Out:
# Enabled: 20956 Disabled: 10610 Total: 31566

# %% [markdown]
# ## Dig into specific rule files and threats

# %% [markdown]
# Okay, now let's try to get information about some rules themselves.
#
# Before getting started, `idstools` parses some information that is not terribly useful (like `action`, `direction`) while leaving other more useful data pieces unparsed. Looking specifically the `header` field for `protocol`, `src_net` and `dest_net`. Following helper function can parse that information.

# %%
def extract_header(header: str) -> dict:
    split = header.split()
    return {
        "proto": split[1],
        "src_net": split[2],
        "src_port": split[3],
        "dest_net": split[5],
        "dest_port": split[6]
    }

# %% [markdown]
# Then build a list of all rules while adding cleaned up filename and that `header` information to dictionary.

# %%
ALL_ET_OPEN_RULES = []

for filename, rules in PARSED_ET_OPEN.items():
    for r in rules:
        r["file"] = os.path.basename(filename)
        r = {**r, **extract_header(r.get("header"))}
        ALL_ET_OPEN_RULES.append(r)

# %% [markdown]
# And rather than attempting to inspect 31k element list, we'll turn the whole thing into a dataframe.

# %%
DF_ET_OPEN_ALL = pd.DataFrame(ALL_ET_OPEN_RULES)

# %% [markdown]
# Filter for only enabled rules. Rules are always commented for a reason!
# * false positives;
# * bad performance;
# * just out of date and irrelevant;

# %%
DF_ET_OPEN_ALL = DF_ET_OPEN_ALL.loc[DF_ET_OPEN_ALL.enabled == True]

# %% [markdown]
# And get a quick peek of ruleset. Just to see what we can work on. Clearly we need to do more filtering and a proper selection of columns. All those *sticky buffer* and *content modifier* columns are totally useless. That's because they always apply to `content` keyword and have no values themselves. Thus, all those vectors are empty.

# %%
DF_ET_OPEN_ALL.head(5)
# Out:
#     enabled action direction group  gid      sid  rev  \
# 7      True  alert        ->  None    1  2018334    2
# 12     True  alert        ->  None    1  2020623    3
# 13     True  alert        ->  None    1  2025004    2
# 14     True  alert        ->  None    1  2025692    2
# 17     True  alert        ->  None    1  2025656    3
#
#                                                   msg flowbits  \
# 7   ET PHISHING Possible Phish - Saved Website Com...       []
# 12  ET PHISHING Possible Tsukuba Banker Edwards Pa...       []
# 13   ET PHISHING Google Drive Phishing Landing Sept 3       []
# 14     ET PHISHING Chase Account Phish Landing Oct 22       []
# 17  ET PHISHING AES Crypto Observed in Javascript ...       []
#
#                                              metadata  ...  \
# 7   [created_at 2014_03_31, former_category INFO, ...  ...
# 12     [created_at 2015_03_05, updated_at 2015_03_05]  ...
# 13  [attack_target Client_Endpoint, created_at 201...  ...
# 14  [created_at 2015_10_22, former_category CURREN...  ...
# 17  [attack_target Client_Endpoint, created_at 201...  ...
#
#    ssh.softwareversion ipopts  http_host sameip detection_filter asn1  \
# 7                  NaN    NaN        NaN    NaN              NaN  NaN
# 12                 NaN    NaN        NaN    NaN              NaN  NaN
# 13                 NaN    NaN        NaN    NaN              NaN  NaN
# 14                 NaN    NaN        NaN    NaN              NaN  NaN
# 17                 NaN    NaN        NaN    NaN              NaN  NaN
#
#    dce_iface ssl_state  tls_sni tls.version
# 7        NaN       NaN      NaN         NaN
# 12       NaN       NaN      NaN         NaN
# 13       NaN       NaN      NaN         NaN
# 14       NaN       NaN      NaN         NaN
# 17       NaN       NaN      NaN         NaN
#
# [5 rows x 139 columns]

# %% [markdown]
# So, we'll build a more consise dataframe. with only those columns we are about. List is not exhaustive and just my selection. **Decide what is relevant to you!**

# %%
DF_ET_OPEN_CONSISE = DF_ET_OPEN_ALL.loc[:, ["proto", "src_net", "dest_net", "sid", "rev", "msg", "file", "flowbits", "metadata", "references", "flow", "raw"] ]

# %% [markdown]
# Notice that our dataframe peek was truncated. This is to avoid exploding your browser, as dataframes can be very big. Following optins can disable that to reveal more information. **But use them with care, make sure you don't call 31k row printout into your browser!**

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %% [markdown]
# Some rule categories are small and can be shown as-is. Rather than creating separate data structures, we'll go data science way and keep everything in one dataframe. Remember, we are exploring, so we never know where that exploration will lead. Better to keep everything at arms reach and just filter if needed. Rely on intermediete data before reaching your goal.
#
# So, to see into `emerging-worm` category, we can simply filter for that file name. Furthermore, we can sort values to make the information easier to grasp. Sorting by rule directionality is already a good trick to visually group rules.

# %%
DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE.file.str.contains("emerging-worm.rules")] \
    .sort_values(by=["src_net", "dest_net"])
# Out:
#       proto    src_net       dest_net      sid  rev  \
# 24753   udp  $HOME_NET  $EXTERNAL_NET  2102004    8
# 24756   tcp  $HOME_NET  $EXTERNAL_NET  2017404    3
# 24758  http  $HOME_NET  $EXTERNAL_NET  2014402    3
# 24761  http  $HOME_NET  $EXTERNAL_NET  2012201    5
# 24763  http  $HOME_NET  $EXTERNAL_NET  2008020    6
# 24764  http  $HOME_NET  $EXTERNAL_NET  2012739    4
# 24759  http        any      $HOME_NET  2018132    5
# 24760  http        any      $HOME_NET  2018155    5
# 24762  http        any      $HOME_NET  2018131    6
#
#                                                                               msg  \
# 24753                          GPL WORM Slammer Worm propagation attempt OUTBOUND
# 24756                                               ET WORM W32/Njw0rm CnC Beacon
# 24758                                          ET WORM W32/Rimecud wg.txt Checkin
# 24761  ET WORM Possible Worm Sohanad.Z or Other Infection Request for setting.nql
# 24763                                     ET WORM Win32.Socks.s HTTP Post Checkin
# 24764                                                ET WORM Rimecud Worm checkin
# 24759                                            ET WORM TheMoon.linksys.router 2
# 24760                                            ET WORM TheMoon.linksys.router 3
# 24762                                            ET WORM TheMoon.linksys.router 1
#
#                       file flowbits  \
# 24753  emerging-worm.rules       []
# 24756  emerging-worm.rules       []
# 24758  emerging-worm.rules       []
# 24761  emerging-worm.rules       []
# 24763  emerging-worm.rules       []
# 24764  emerging-worm.rules       []
# 24759  emerging-worm.rules       []
# 24760  emerging-worm.rules       []
# 24762  emerging-worm.rules       []
#
#                                                                    metadata  \
# 24753                        [created_at 2010_09_23, updated_at 2010_09_23]
# 24756  [created_at 2013_08_31, former_category WORM, updated_at 2013_08_31]
# 24758                        [created_at 2012_03_19, updated_at 2020_04_21]
# 24761                        [created_at 2011_01_17, updated_at 2020_08_04]
# 24763                        [created_at 2010_07_30, updated_at 2020_08_18]
# 24764                        [created_at 2011_04_29, updated_at 2020_10_13]
# 24759                        [created_at 2014_02_13, updated_at 2020_07_07]
# 24760                        [created_at 2014_02_18, updated_at 2020_07_07]
# 24762                        [created_at 2014_02_13, updated_at 2020_08_18]
#
#                                                                                                                                                                                references  \
# 24753                                                                                  [bugtraq,5310, bugtraq,5311, cve,2002-0649, nessus,11214, url,vil.nai.com/vil/content/v_99992.htm]
# 24756  [url,www.fireeye.com/blog/technical/malware-research/2013/08/njw0rm-brother-from-the-same-mother.html, md5,4c60493b14c666c56db163203e819272, md5,b0e1d20accd9a2ed29cdacb803e4a89d]
# 24758      [md5,a89f7289d5cce821a194542e90026082, md5,fd56ce176889d4fbe588760a1da6462b, url,www.microsoft.com/security/portal/Threat/Encyclopedia/Entry.aspx?Name=Worm%3AWin32%2FRimecud]
# 24761                                                                                                         [url,www.threatexpert.com/report.aspx?md5=a70aad8f27957702febfa162556dc5b5]
# 24763                                                                                                                                               [url,doc.emergingthreats.net/2008020]
# 24764                                                                                                         [url,www.threatexpert.com/report.aspx?md5=9623efa133415d19c941ef92a4f921fc]
# 24759                                                               [url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630, url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/]
# 24760                           [url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630, url,exploit-db.com/exploits/31683/, url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/]
# 24762                                                                                                                         [url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630]
#
#                         flow  \
# 24753                    NaN
# 24756  established,to_server
# 24758  established,to_server
# 24761  established,to_server
# 24763  established,to_server
# 24764  established,to_server
# 24759  to_server,established
# 24760  to_server,established
# 24762            established
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                raw
# 24753                                                                alert udp $HOME_NET any -> $EXTERNAL_NET 1434 (msg:"GPL WORM Slammer Worm propagation attempt OUTBOUND"; content:"|04|"; depth:1; content:"|81 F1 03 01 04 9B 81 F1|"; content:"sock"; content:"send"; reference:bugtraq,5310; reference:bugtraq,5311; reference:cve,2002-0649; reference:nessus,11214; reference:url,vil.nai.com/vil/content/v_99992.htm; classtype:misc-attack; sid:2102004; rev:8; metadata:created_at 2010_09_23, updated_at 2010_09_23;)
# 24756  alert tcp $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM W32/Njw0rm CnC Beacon"; flow:established,to_server; content:"lv0njxq80"; depth:9; content:"njxq80"; distance:0; reference:url,www.fireeye.com/blog/technical/malware-research/2013/08/njw0rm-brother-from-the-same-mother.html; reference:md5,4c60493b14c666c56db163203e819272; reference:md5,b0e1d20accd9a2ed29cdacb803e4a89d; classtype:command-and-control; sid:2017404; rev:3; metadata:created_at 2013_08_31, former_category WORM, updated_at 2013_08_31;)
# 24758                                                         alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM W32/Rimecud wg.txt Checkin"; flow:established,to_server; http.uri; content:"/wg.txt"; reference:md5,a89f7289d5cce821a194542e90026082; reference:md5,fd56ce176889d4fbe588760a1da6462b; reference:url,www.microsoft.com/security/portal/Threat/Encyclopedia/Entry.aspx?Name=Worm%3AWin32%2FRimecud; classtype:trojan-activity; sid:2014402; rev:3; metadata:created_at 2012_03_19, updated_at 2020_04_21;)
# 24761                                                                                                                           alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM Possible Worm Sohanad.Z or Other Infection Request for setting.nql"; flow:established,to_server; http.uri; content:"/setting.nql"; nocase; reference:url,www.threatexpert.com/report.aspx?md5=a70aad8f27957702febfa162556dc5b5; classtype:trojan-activity; sid:2012201; rev:5; metadata:created_at 2011_01_17, updated_at 2020_08_04;)
# 24763                                                                                                                     alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM Win32.Socks.s HTTP Post Checkin"; flow:established,to_server; http.method; content:"POST"; http.uri; content:".php"; http.request_body; content:"proc=[System Process]|0a|"; depth:22; reference:url,doc.emergingthreats.net/2008020; classtype:trojan-activity; sid:2008020; rev:6; metadata:created_at 2010_07_30, updated_at 2020_08_18;)
# 24764                                                       alert http $HOME_NET any -> $EXTERNAL_NET any (msg:"ET WORM Rimecud Worm checkin"; flow:established,to_server; http.method; content:"GET"; http.uri; content:"/taskx.txt"; fast_pattern; http.user_agent; content:"Mozilla/3.0 (compatible|3b 20|Indy Library)"; depth:38; reference:url,www.threatexpert.com/report.aspx?md5=9623efa133415d19c941ef92a4f921fc; classtype:trojan-activity; sid:2012739; rev:4; metadata:created_at 2011_04_29, updated_at 2020_10_13;)
# 24759                                                                                                   alert http any any -> $HOME_NET 8080 (msg:"ET WORM TheMoon.linksys.router 2"; flow:to_server,established; http.method; content:"POST"; http.uri; content:"/tmUnblock.cgi"; reference:url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630; reference:url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/; classtype:trojan-activity; sid:2018132; rev:5; metadata:created_at 2014_02_13, updated_at 2020_07_07;)
# 24760                                                    alert http any any -> $HOME_NET 8080 (msg:"ET WORM TheMoon.linksys.router 3"; flow:to_server,established; http.method; content:"POST"; http.uri; content:"/hndUnblock.cgi"; reference:url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630; reference:url,exploit-db.com/exploits/31683/; reference:url,devttys0.com/2014/02/wrt120n-fprintf-stack-overflow/; classtype:trojan-activity; sid:2018155; rev:5; metadata:created_at 2014_02_18, updated_at 2020_07_07;)
# 24762                                                                                                                          alert http any any -> $HOME_NET 8080 (msg:"ET WORM TheMoon.linksys.router 1"; flow:established; urilen:7; http.method; content:"GET"; http.uri; content:"/HNAP1/"; http.host; pcre:"/^(?:[0-9]{1,3}\.){3}[0-9]{1,3}$/"; reference:url,isc.sans.edu/forums/diary/Linksys+Worm+Captured/17630; classtype:trojan-activity; sid:2018131; rev:6; metadata:created_at 2014_02_13, updated_at 2020_08_18;)

# %% [markdown]
# **PS! Jupyter is a data science tool, and thus caters to that audience. This can lead to silly things like formating rule header like mathematical formula**.
#
# However, really good stuff is in `malware` and `mobile_malware` categories. And those are big. Too big to explore with full dumps. So, let's limit the scope only to a *recent hotness*.

# %%
RULES_SUNBURST = DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE.msg.str.contains("SUNBURST", re.IGNORECASE)] \
    .sort_values(by=["proto", "src_net", "dest_net", "msg"]) \
    .drop(columns=["flowbits", "raw", "metadata", "flow"]) \
    .explode("references")

# %% [markdown]
# This is a bit more involved, but in many ways is similar to a database query.
# * First, we locate all rules containing `SUNBURST` keyword. Sometimes this information is in `tag` or `metadata`, but dont count on it. And it's not very consistent.
# * Then we sort values to make the frame visually easier to explore. Pandas even let's us sort by multiple values. That's why I wanted to parse `proto`, `src_net` and `dest_net` from the rule header! With those fields, we get a much better organized view.
# * Then drop some columns (from view) that are just noise:
#   * `flowbits` are not really that relevant for current explorations, rule content should be listed separately anyway
#   * likewise `raw` rule just makes dataframe as a whole more difficult to assess, but it can always be added back if we need to check the content!
#   * `metadata` does not hold much useful information and is a list, which again makes frame messy
#   * `flow` is a bit redundant with sorted `src_net` and `dest_net` view. Good info, but we only have limited screen real-estate
#  * Finally, `references` holds lists, but we can use `explode()` method to unpack each reference to separate row. **This duplicates other rule row elements!** But not a big deal for this case.

# %%
RULES_SUNBURST
# Out:
#       proto        src_net       dest_net      sid  rev  \
# 10284   dns      $HOME_NET            any  2031392    1
# 10283   dns      $HOME_NET            any  2031391    1
# 10281   dns      $HOME_NET            any  2031389    1
# 10282   dns      $HOME_NET            any  2031390    1
# 10279   dns      $HOME_NET            any  2031387    1
# 10280   dns      $HOME_NET            any  2031388    1
# 10308   dns      $HOME_NET            any  2031359    3
# 10276   dns      $HOME_NET            any  2031324    3
# 10260   dns      $HOME_NET            any  2031331    2
# 10255   dns      $HOME_NET            any  2031326    2
# 10264   dns      $HOME_NET            any  2031335    2
# 10256   dns      $HOME_NET            any  2031327    2
# 10258   dns      $HOME_NET            any  2031329    2
# 10259   dns      $HOME_NET            any  2031330    2
# 10261   dns      $HOME_NET            any  2031332    2
# 10254   dns      $HOME_NET            any  2031325    2
# 10263   dns      $HOME_NET            any  2031334    2
# 10257   dns      $HOME_NET            any  2031328    2
# 10262   dns      $HOME_NET            any  2031333    2
# 10277  http      $HOME_NET  $EXTERNAL_NET  2031338    3
# 10238  http      $HOME_NET  $EXTERNAL_NET  2031349    2
# 10236  http      $HOME_NET  $EXTERNAL_NET  2031347    2
# 10237  http      $HOME_NET  $EXTERNAL_NET  2031348    2
# 10239  http      $HOME_NET  $EXTERNAL_NET  2031350    2
# 10240  http      $HOME_NET  $EXTERNAL_NET  2031351    2
# 10232  http      $HOME_NET  $EXTERNAL_NET  2031336    2
# 10233  http      $HOME_NET  $EXTERNAL_NET  2031337    2
# 10234  http      $HOME_NET  $EXTERNAL_NET  2031339    2
# 10235  http      $HOME_NET  $EXTERNAL_NET  2031340    2
# 10296   tls  $EXTERNAL_NET      $HOME_NET  2031385    2
# 10295   tls  $EXTERNAL_NET      $HOME_NET  2031384    2
# 10293   tls  $EXTERNAL_NET      $HOME_NET  2031382    2
# 10294   tls  $EXTERNAL_NET      $HOME_NET  2031383    2
# 10291   tls  $EXTERNAL_NET      $HOME_NET  2031380    2
# 10292   tls  $EXTERNAL_NET      $HOME_NET  2031381    2
# 10278   tls  $EXTERNAL_NET      $HOME_NET  2031341    3
# 10298   tls  $EXTERNAL_NET      $HOME_NET  2031344    3
# 10302   tls  $EXTERNAL_NET      $HOME_NET  2031342    3
# 10305   tls  $EXTERNAL_NET      $HOME_NET  2031343    3
# 10307   tls  $EXTERNAL_NET      $HOME_NET  2031361    2
# 10299   tls  $EXTERNAL_NET      $HOME_NET  2031345    3
# 10300   tls  $EXTERNAL_NET      $HOME_NET  2031346    3
# 10306   tls  $EXTERNAL_NET      $HOME_NET  2031360    2
# 10290   tls      $HOME_NET  $EXTERNAL_NET  2031398    1
# 10289   tls      $HOME_NET  $EXTERNAL_NET  2031397    1
# 10287   tls      $HOME_NET  $EXTERNAL_NET  2031395    1
# 10288   tls      $HOME_NET  $EXTERNAL_NET  2031396    1
# 10285   tls      $HOME_NET  $EXTERNAL_NET  2031393    1
# 10286   tls      $HOME_NET  $EXTERNAL_NET  2031394    1
# 10270   tls      $HOME_NET  $EXTERNAL_NET  2031366    1
# 10274   tls      $HOME_NET  $EXTERNAL_NET  2031370    1
# 10269   tls      $HOME_NET  $EXTERNAL_NET  2031365    1
# 10271   tls      $HOME_NET  $EXTERNAL_NET  2031367    1
# 10267   tls      $HOME_NET  $EXTERNAL_NET  2031363    1
# 10268   tls      $HOME_NET  $EXTERNAL_NET  2031364    1
# 10266   tls      $HOME_NET  $EXTERNAL_NET  2031362    1
# 10272   tls      $HOME_NET  $EXTERNAL_NET  2031368    1
# 10273   tls      $HOME_NET  $EXTERNAL_NET  2031369    1
#
#                                                                                                msg  \
# 10284                 ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to globalnetworkissues .com
# 10283                           ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to kubecloud .com
# 10281                          ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to lcomputers .com
# 10282                        ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to seobundlekit .com
# 10279                 ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to solartrackingsystem .net
# 10280                            ET MALWARE Dark Halo/SUNBURST Related DNS Lookup to webcodez .com
# 10308                                           ET MALWARE [Fireeye] Observed SUNBURST DGA Request
# 10276                          ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to avsvmcloud .com
# 10260                      ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to databasegalore .com
# 10255                        ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to deftsecurity .com
# 10264                      ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to digitalcollege .org
# 10256                      ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to freescanonline .com
# 10258                        ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to highdatabase .com
# 10259                        ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to incomeupdate .com
# 10261                         ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to panhardware .com
# 10254                         ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to thedoccloud .com
# 10263                   ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to virtualdataserver .com
# 10257                        ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to websitetheme .com
# 10262                           ET MALWARE [Fireeye] SUNBURST Related DNS Lookup to zupertech .com
# 10277                       ET MALWARE [Fireeye] Backdoor.SUNBURST HTTP Request to avsvmcloud .com
# 10238                     ET MALWARE [Fireeye] Backdoor.SUNBURST HTTP Request to deftsecurity .com
# 10236                   ET MALWARE [Fireeye] Backdoor.SUNBURST HTTP Request to digitalcollege .org
# 10237                   ET MALWARE [Fireeye] Backdoor.SUNBURST HTTP Request to freescanonline .com
# 10239                      ET MALWARE [Fireeye] Backdoor.SUNBURST HTTP Request to thedoccloud .com
# 10240                ET MALWARE [Fireeye] Backdoor.SUNBURST HTTP Request to virtualdataserver .com
# 10232                                                    ET MALWARE [Fireeye] Backdoor.SUNBURST M1
# 10233                                                    ET MALWARE [Fireeye] Backdoor.SUNBURST M2
# 10234                                                    ET MALWARE [Fireeye] Backdoor.SUNBURST M3
# 10235                                                    ET MALWARE [Fireeye] Backdoor.SUNBURST M4
# 10296                    ET MALWARE Dark Halo/SUNBURST SSL Cert Inbound (globalnetworkissues .com)
# 10295                              ET MALWARE Dark Halo/SUNBURST SSL Cert Inbound (kubecloud .com)
# 10293                             ET MALWARE Dark Halo/SUNBURST SSL Cert Inbound (lcomputers .com)
# 10294                           ET MALWARE Dark Halo/SUNBURST SSL Cert Inbound (seobundlekit .com)
# 10291                    ET MALWARE Dark Halo/SUNBURST SSL Cert Inbound (solartrackingsystem .net)
# 10292                               ET MALWARE Dark Halo/SUNBURST SSL Cert Inbound (webcodez .com)
# 10278                    ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (avsvmcloud .com)
# 10298                  ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (deftsecurity .com)
# 10302                ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (digitalcollege .org)
# 10305                ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (freescanonline .com)
# 10307                  ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (highdatabase .com)
# 10299                   ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (thedoccloud .com)
# 10300             ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (virtualdataserver .com)
# 10306                  ET MALWARE [Fireeye] Backdoor.SUNBURST SSL Cert Inbound (websitetheme .com)
# 10290               ET MALWARE Dark Halo/SUNBURST CnC Domain (globalnetworkissues .com in TLS SNI)
# 10289                         ET MALWARE Dark Halo/SUNBURST CnC Domain (kubecloud .com in TLS SNI)
# 10287                        ET MALWARE Dark Halo/SUNBURST CnC Domain (lcomputers .com in TLS SNI)
# 10288                      ET MALWARE Dark Halo/SUNBURST CnC Domain (seobundlekit .com in TLS SNI)
# 10285               ET MALWARE Dark Halo/SUNBURST CnC Domain (solartrackingsystem .net in TLS SNI)
# 10286                          ET MALWARE Dark Halo/SUNBURST CnC Domain (webcodez .com in TLS SNI)
# 10270  ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (databasegalore .com in TLS SNI)
# 10274    ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (deftsecurity .com in TLS SNI)
# 10269  ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (freescanonline .com in TLS SNI)
# 10271    ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (highdatabase .com in TLS SNI)
# 10267    ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (incomeudpate .com in TLS SNI)
# 10268     ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (panhardware .com in TLS SNI)
# 10266     ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (thedoccloud .com in TLS SNI)
# 10272    ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (websitetheme .com in TLS SNI)
# 10273       ET MALWARE [Fireeye] Observed Backdoor.SUNBURST CnC Domain (zupertech .com in TLS SNI)
#
#                          file  \
# 10284  emerging-malware.rules
# 10283  emerging-malware.rules
# 10281  emerging-malware.rules
# 10282  emerging-malware.rules
# 10279  emerging-malware.rules
# 10280  emerging-malware.rules
# 10308  emerging-malware.rules
# 10276  emerging-malware.rules
# 10260  emerging-malware.rules
# 10255  emerging-malware.rules
# 10264  emerging-malware.rules
# 10256  emerging-malware.rules
# 10258  emerging-malware.rules
# 10259  emerging-malware.rules
# 10261  emerging-malware.rules
# 10254  emerging-malware.rules
# 10263  emerging-malware.rules
# 10257  emerging-malware.rules
# 10262  emerging-malware.rules
# 10277  emerging-malware.rules
# 10238  emerging-malware.rules
# 10236  emerging-malware.rules
# 10237  emerging-malware.rules
# 10239  emerging-malware.rules
# 10240  emerging-malware.rules
# 10232  emerging-malware.rules
# 10233  emerging-malware.rules
# 10234  emerging-malware.rules
# 10235  emerging-malware.rules
# 10296  emerging-malware.rules
# 10295  emerging-malware.rules
# 10293  emerging-malware.rules
# 10294  emerging-malware.rules
# 10291  emerging-malware.rules
# 10292  emerging-malware.rules
# 10278  emerging-malware.rules
# 10298  emerging-malware.rules
# 10302  emerging-malware.rules
# 10305  emerging-malware.rules
# 10307  emerging-malware.rules
# 10299  emerging-malware.rules
# 10300  emerging-malware.rules
# 10306  emerging-malware.rules
# 10290  emerging-malware.rules
# 10289  emerging-malware.rules
# 10287  emerging-malware.rules
# 10288  emerging-malware.rules
# 10285  emerging-malware.rules
# 10286  emerging-malware.rules
# 10270  emerging-malware.rules
# 10274  emerging-malware.rules
# 10269  emerging-malware.rules
# 10271  emerging-malware.rules
# 10267  emerging-malware.rules
# 10268  emerging-malware.rules
# 10266  emerging-malware.rules
# 10272  emerging-malware.rules
# 10273  emerging-malware.rules
#
#                                                                                                                                         references
# 10284                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10283                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10281                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10282                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10279                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10280                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10308  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10276  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10260  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10255  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10264  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10256  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10258  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10259  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10261  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10254  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10263  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10257  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10262  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10277  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10238  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10236  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10237  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10239  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10240  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10232  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10233  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10234  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10235  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10296                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10295                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10293                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10294                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10291                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10292                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10278  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10298  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10302  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10305  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10307  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10299  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10300  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10306  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10290                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10289                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10287                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10288                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10285                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10286                                      url,www.volexity.com/blog/2020/12/14/dark-halo-leverages-solarwinds-compromise-to-breach-organizations/
# 10270  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10274  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10269  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10271  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10267  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10268  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10266  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10272  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html
# 10273  url,www.fireeye.com/blog/threat-research/2020/12/evasive-attacker-leverages-solarwinds-supply-chain-compromises-with-sunburst-backdoor.html

# %% [markdown]
# Same exploration can be repeated for other relevant threats. For example, I bet many students are interested in `Cobalt Strike` rules.

# %%
RULES_COBALT_STRIKE = DF_ET_OPEN_CONSISE \
    .loc[DF_ET_OPEN_CONSISE \
    .msg.str.contains("Cobalt Strike|CobaltStrike", re.IGNORECASE)] \
    .drop(columns=["metadata", "flowbits"]) \
    .explode("references") \
    .sort_values(by=["msg"]) \
    .drop(columns=["raw"])

# %%
RULES_COBALT_STRIKE
# Out:
#       proto        src_net       dest_net      sid  rev  \
# 25078   tls  $EXTERNAL_NET      $HOME_NET  2023629    4
# 12076   tls  $EXTERNAL_NET      $HOME_NET  2028832    1
# 12075   tls      $HOME_NET  $EXTERNAL_NET  2028831    1
# 7681   http      $HOME_NET  $EXTERNAL_NET  2025636    3
# 9960   http      $HOME_NET  $EXTERNAL_NET  2029744    2
# 5406   http      $HOME_NET  $EXTERNAL_NET  2029978    1
# 5406   http      $HOME_NET  $EXTERNAL_NET  2029978    1
# 5404   http      $HOME_NET  $EXTERNAL_NET  2029977    2
# 5404   http      $HOME_NET  $EXTERNAL_NET  2029977    2
# 5327   http      $HOME_NET  $EXTERNAL_NET  2029740    1
# 5328   http      $HOME_NET  $EXTERNAL_NET  2029741    1
# 9958   http      $HOME_NET  $EXTERNAL_NET  2029742    2
# 9959   http      $HOME_NET  $EXTERNAL_NET  2029743    2
# 6316   http      $HOME_NET  $EXTERNAL_NET  2030347    2
# 6301   http      $HOME_NET  $EXTERNAL_NET  2030344    1
# 5210   http      $HOME_NET  $EXTERNAL_NET  2029381    1
# 6863    udp  $EXTERNAL_NET      $HOME_NET  2026040    7
# 5054    smb            any      $HOME_NET  2027325    2
# 5054    smb            any      $HOME_NET  2027325    2
# 5054    smb            any      $HOME_NET  2027325    2
# 8749    dns      $HOME_NET            any  2024497    6
# 8749    dns      $HOME_NET            any  2024497    6
# 5235    tls  $EXTERNAL_NET      $HOME_NET  2029491    1
# 10363   tls      $HOME_NET  $EXTERNAL_NET  2031469    1
# 5954    dns      $HOME_NET            any  2030112    1
# 4767   http      $HOME_NET  $EXTERNAL_NET  2028598    2
# 10057   tls      $HOME_NET  $EXTERNAL_NET  2030459    2
# 10058   tls      $HOME_NET  $EXTERNAL_NET  2030461    2
# 6394    tls      $HOME_NET  $EXTERNAL_NET  2030456    1
# 6392    tls      $HOME_NET  $EXTERNAL_NET  2030454    1
# 10059   tls      $HOME_NET  $EXTERNAL_NET  2030463    2
# 6390    tls      $HOME_NET  $EXTERNAL_NET  2030452    1
# 10061   tls      $HOME_NET  $EXTERNAL_NET  2030467    2
# 6388    tls      $HOME_NET  $EXTERNAL_NET  2030450    1
# 6386    tls      $HOME_NET  $EXTERNAL_NET  2030448    1
# 10060   tls      $HOME_NET  $EXTERNAL_NET  2030465    2
# 10355   dns      $HOME_NET            any  2031452    1
# 10354   tls      $HOME_NET  $EXTERNAL_NET  2031451    1
# 5953    tls  $EXTERNAL_NET      $HOME_NET  2030111    1
# 8948    tls  $EXTERNAL_NET      $HOME_NET  2030901    1
# 8950    tls  $EXTERNAL_NET      $HOME_NET  2030902    1
# 8952    tls  $EXTERNAL_NET      $HOME_NET  2030903    1
# 9469    tls  $EXTERNAL_NET      $HOME_NET  2031069    1
# 9469    tls  $EXTERNAL_NET      $HOME_NET  2031069    1
# 9608    tls  $EXTERNAL_NET      $HOME_NET  2031119    1
# 5323    tls  $EXTERNAL_NET      $HOME_NET  2029730    1
# 6531    tls  $EXTERNAL_NET      $HOME_NET  2030635    1
# 5306    tls  $EXTERNAL_NET      $HOME_NET  2029639    1
# 6321    tls  $EXTERNAL_NET      $HOME_NET  2030349    1
# 7987    tls  $EXTERNAL_NET      $HOME_NET  2027082    3
# 6255    tls  $EXTERNAL_NET      $HOME_NET  2030252    1
# 6389    tls  $EXTERNAL_NET      $HOME_NET  2030451    1
# 6391    tls  $EXTERNAL_NET      $HOME_NET  2030453    1
# 6393    tls  $EXTERNAL_NET      $HOME_NET  2030455    1
# 6400    tls  $EXTERNAL_NET      $HOME_NET  2030466    1
# 6399    tls  $EXTERNAL_NET      $HOME_NET  2030464    1
# 6395    tls  $EXTERNAL_NET      $HOME_NET  2030457    1
# 6396    tls  $EXTERNAL_NET      $HOME_NET  2030458    1
# 6398    tls  $EXTERNAL_NET      $HOME_NET  2030462    1
# 7484    tls  $EXTERNAL_NET      $HOME_NET  2030867    1
# 6397    tls  $EXTERNAL_NET      $HOME_NET  2030460    1
# 6387    tls  $EXTERNAL_NET      $HOME_NET  2030449    1
# 6358   http  $EXTERNAL_NET      $HOME_NET  2030400    2
# 9707    tls  $EXTERNAL_NET      $HOME_NET  2031136    2
# 9707    tls  $EXTERNAL_NET      $HOME_NET  2031136    2
# 9707    tls  $EXTERNAL_NET      $HOME_NET  2031136    2
# 9706    tls  $EXTERNAL_NET      $HOME_NET  2031135    2
# 9706    tls  $EXTERNAL_NET      $HOME_NET  2031135    2
# 9493    tls  $EXTERNAL_NET      $HOME_NET  2031133    1
# 9493    tls  $EXTERNAL_NET      $HOME_NET  2031133    1
# 10179   tls  $EXTERNAL_NET      $HOME_NET  2031134    3
# 10179   tls  $EXTERNAL_NET      $HOME_NET  2031134    3
# 10179   tls  $EXTERNAL_NET      $HOME_NET  2031134    3
# 7159   http  $EXTERNAL_NET      $HOME_NET  2024771    3
# 7400   http      $HOME_NET  $EXTERNAL_NET  2028588    2
# 7400   http      $HOME_NET  $EXTERNAL_NET  2028588    2
# 7456   http      $HOME_NET  $EXTERNAL_NET  2028591    4
# 7456   http      $HOME_NET  $EXTERNAL_NET  2028591    4
# 4579   http  $EXTERNAL_NET      $HOME_NET  2028589    1
# 4579   http  $EXTERNAL_NET      $HOME_NET  2028589    1
# 4580   http  $EXTERNAL_NET      $HOME_NET  2028590    1
# 4580   http  $EXTERNAL_NET      $HOME_NET  2028590    1
# 10105  http      $HOME_NET  $EXTERNAL_NET  2025635    5
#
#                                                                                            msg  \
# 25078                  ET HUNTING Suspicious Empty SSL Certificate - Observed in Cobalt Strike
# 12076                             ET JA3 Hash - Suspected Cobalt Strike Malleable C2 (ja3s) M1
# 12075                              ET JA3 Hash - Suspected Cobalt Strike Malleable C2 M1 (set)
# 7681                                                     ET MALWARE Cobalt Strike Exfiltration
# 9960                                        ET MALWARE Cobalt Strike Malleable C2 (Adobe RTMP)
# 5406                                            ET MALWARE Cobalt Strike Malleable C2 (Custom)
# 5406                                            ET MALWARE Cobalt Strike Malleable C2 (Custom)
# 5404                                            ET MALWARE Cobalt Strike Malleable C2 (Custom)
# 5404                                            ET MALWARE Cobalt Strike Malleable C2 (Custom)
# 5327                                         ET MALWARE Cobalt Strike Malleable C2 (Havex APT)
# 5328                                      ET MALWARE Cobalt Strike Malleable C2 (Magnitude EK)
# 9958                                       ET MALWARE Cobalt Strike Malleable C2 (Meterpreter)
# 9959                                          ET MALWARE Cobalt Strike Malleable C2 (OneDrive)
# 6316                            ET MALWARE Cobalt Strike Malleable C2 (Safebrowse Profile) GET
# 6301                           ET MALWARE Cobalt Strike Malleable C2 (Safebrowse Profile) POST
# 5210                     ET MALWARE Cobalt Strike Malleable C2 Request (Stackoverflow Profile)
# 6863                                               ET MALWARE CobaltStrike DNS Beacon Response
# 5054                    ET MALWARE CobaltStrike SMB P2P Default Msagent Named Pipe Interaction
# 5054                    ET MALWARE CobaltStrike SMB P2P Default Msagent Named Pipe Interaction
# 5054                    ET MALWARE CobaltStrike SMB P2P Default Msagent Named Pipe Interaction
# 8749                ET MALWARE CopyKittens Cobalt Strike DNS Lookup (cloudflare-analyse . com)
# 8749                ET MALWARE CopyKittens Cobalt Strike DNS Lookup (cloudflare-analyse . com)
# 5235                         ET MALWARE Malicious SSL Certificate detected (Cobalt Strike CnC)
# 10363                 ET MALWARE Observed Cobalt Strike CnC Domain in TLS SNI (cs .lg22l .com)
# 5954                              ET MALWARE Observed Cobalt Strike Stager Domain in DNS Query
# 4767                                              ET MALWARE Observed Cobalt Strike User-Agent
# 10057                                   ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 10058                                   ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 6394                                    ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 6392                                    ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 10059                                   ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 6390                                    ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 10061                                   ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 6388                                    ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 6386                                    ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 10060                                   ET MALWARE Observed CobaltStrike CnC Domain in TLS SNI
# 10355                 ET MALWARE Observed CobaltStrike/TEARDROP CnC Domain Domain in DNS Query
# 10354  ET MALWARE Observed CobaltStrike/TEARDROP CnC Domain Domain in TLS SNI (mobilnweb .com)
# 5953                                  ET MALWARE Observed Default CobaltStrike SSL Certificate
# 8948                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 8950                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 8952                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 9469                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 9469                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 9608                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 5323                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 6531                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 5306                                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike CnC)
# 6321                ET MALWARE Observed Malicious SSL Cert (Cobalt Strike Malleable C2 Domain)
# 7987                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6255                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6389                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6391                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6393                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6400                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6399                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6395                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6396                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6398                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 7484                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6397                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6387                                 ET MALWARE Observed Malicious SSL Cert (CobaltStrike CnC)
# 6358                                     ET MALWARE Possible IndigoDrop/Cobalt Strike Download
# 9707              ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (Mountainvew)
# 9707              ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (Mountainvew)
# 9707              ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (Mountainvew)
# 9706                    ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (Texsa)
# 9706                    ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (Texsa)
# 9493                      ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (lol)
# 9493                      ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (lol)
# 10179                  ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (office)
# 10179                  ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (office)
# 10179                  ET MALWARE Possible UNC1878 Cobalt Strike CnC SSL Cert Inbound (office)
# 7159                                    ET MALWARE [PTsecurity] Possible Cobalt Strike payload
# 7400                        ET MALWARE [TGI] Cobalt Strike Malleable C2 Request (O365 Profile)
# 7400                        ET MALWARE [TGI] Cobalt Strike Malleable C2 Request (O365 Profile)
# 7456                     ET MALWARE [TGI] Cobalt Strike Malleable C2 Request (YouTube Profile)
# 7456                     ET MALWARE [TGI] Cobalt Strike Malleable C2 Request (YouTube Profile)
# 4579                    ET MALWARE [TGI] Cobalt Strike Malleable C2 Response (O365 Profile) M2
# 4579                    ET MALWARE [TGI] Cobalt Strike Malleable C2 Response (O365 Profile) M2
# 4580                    ET MALWARE [TGI] Cobalt Strike Malleable C2 Response (YouTube Profile)
# 4580                    ET MALWARE [TGI] Cobalt Strike Malleable C2 Response (YouTube Profile)
# 10105                                               ET MALWARE [eSentire] Cobalt Strike Beacon
#
#                          file  \
# 25078  emerging-hunting.rules
# 12076      emerging-ja3.rules
# 12075      emerging-ja3.rules
# 7681   emerging-malware.rules
# 9960   emerging-malware.rules
# 5406   emerging-malware.rules
# 5406   emerging-malware.rules
# 5404   emerging-malware.rules
# 5404   emerging-malware.rules
# 5327   emerging-malware.rules
# 5328   emerging-malware.rules
# 9958   emerging-malware.rules
# 9959   emerging-malware.rules
# 6316   emerging-malware.rules
# 6301   emerging-malware.rules
# 5210   emerging-malware.rules
# 6863   emerging-malware.rules
# 5054   emerging-malware.rules
# 5054   emerging-malware.rules
# 5054   emerging-malware.rules
# 8749   emerging-malware.rules
# 8749   emerging-malware.rules
# 5235   emerging-malware.rules
# 10363  emerging-malware.rules
# 5954   emerging-malware.rules
# 4767   emerging-malware.rules
# 10057  emerging-malware.rules
# 10058  emerging-malware.rules
# 6394   emerging-malware.rules
# 6392   emerging-malware.rules
# 10059  emerging-malware.rules
# 6390   emerging-malware.rules
# 10061  emerging-malware.rules
# 6388   emerging-malware.rules
# 6386   emerging-malware.rules
# 10060  emerging-malware.rules
# 10355  emerging-malware.rules
# 10354  emerging-malware.rules
# 5953   emerging-malware.rules
# 8948   emerging-malware.rules
# 8950   emerging-malware.rules
# 8952   emerging-malware.rules
# 9469   emerging-malware.rules
# 9469   emerging-malware.rules
# 9608   emerging-malware.rules
# 5323   emerging-malware.rules
# 6531   emerging-malware.rules
# 5306   emerging-malware.rules
# 6321   emerging-malware.rules
# 7987   emerging-malware.rules
# 6255   emerging-malware.rules
# 6389   emerging-malware.rules
# 6391   emerging-malware.rules
# 6393   emerging-malware.rules
# 6400   emerging-malware.rules
# 6399   emerging-malware.rules
# 6395   emerging-malware.rules
# 6396   emerging-malware.rules
# 6398   emerging-malware.rules
# 7484   emerging-malware.rules
# 6397   emerging-malware.rules
# 6387   emerging-malware.rules
# 6358   emerging-malware.rules
# 9707   emerging-malware.rules
# 9707   emerging-malware.rules
# 9707   emerging-malware.rules
# 9706   emerging-malware.rules
# 9706   emerging-malware.rules
# 9493   emerging-malware.rules
# 9493   emerging-malware.rules
# 10179  emerging-malware.rules
# 10179  emerging-malware.rules
# 10179  emerging-malware.rules
# 7159   emerging-malware.rules
# 7400   emerging-malware.rules
# 7400   emerging-malware.rules
# 7456   emerging-malware.rules
# 7456   emerging-malware.rules
# 4579   emerging-malware.rules
# 4579   emerging-malware.rules
# 4580   emerging-malware.rules
# 4580   emerging-malware.rules
# 10105  emerging-malware.rules
#
#                                                                                                                     references  \
# 25078                                                                                                                      NaN
# 12076                                                                                                                      NaN
# 12075                                                                                                                      NaN
# 7681                                                                                                                       NaN
# 9960                                              url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/rtmp.profile
# 5406                                                                                      md5,79bbe1365fb7532613823ce3e0cac499
# 5406                                                                     url,twitter.com/CyberRaiju/status/1249272772963864576
# 5404                                                                     url,twitter.com/CyberRaiju/status/1249272772963864576
# 5404                                                                                      md5,79bbe1365fb7532613823ce3e0cac499
# 5327                                                url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/APT/havex.profile
# 5328                                     url,github.com//rsmudge/Malleable-C2-Profiles/blob/master/crimeware/magnitude.profile
# 9958                                          url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/APT/meterpreter.profile
# 9959                                  url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/onedrive_getonly.profile
# 6316                                      url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/safebrowsing.profile
# 6301                                      url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/safebrowsing.profile
# 5210                                                                               url,github.com/xx0hcd/Malleable-C2-Profiles
# 6863                                                                                   url,www.youtube.com/watch?v=zAB5G-QOyx8
# 5054                                                                 url,blog.cobaltstrike.com/2015/10/07/named-pipe-pivoting/
# 5054                                           url,posts.specterops.io/designing-peer-to-peer-command-and-control-ad2c61740456
# 5054                                                                                url,www.cobaltstrike.com/help-malleable-c2
# 8749                                             url,www.clearskysec.com/wp-content/uploads/2017/07/Operation_Wilted_Tulip.pdf
# 8749                                                                                      md5,752240cddda5acb5e8d026cef82e2b54
# 5235                                                                                      md5,e4224469bd75b63fa0cebd33c53b4d85
# 10363                                                                                     md5,774419bb738a2a4fa18aacee88850d2c
# 5954                                          url,fireeye.com/blog/threat-research/2020/03/the-cycle-of-adversary-pursuit.html
# 4767                                                                                                                       NaN
# 10057                                                                                                                      NaN
# 10058                                                                                                                      NaN
# 6394                                                                                                                       NaN
# 6392                                                                                                                       NaN
# 10059                                                                                                                      NaN
# 6390                                                                                                                       NaN
# 10061                                                                                                                      NaN
# 6388                                                                                                                       NaN
# 6386                                                                                                                       NaN
# 10060                                                                                                                      NaN
# 10355                                                  url,unit42.paloaltonetworks.com/solarstorm-supply-chain-attack-timeline
# 10354                                                  url,unit42.paloaltonetworks.com/solarstorm-supply-chain-attack-timeline
# 5953                                          url,fireeye.com/blog/threat-research/2020/03/the-cycle-of-adversary-pursuit.html
# 8948                                                                      url,twitter.com/bryceabdo/status/1308802052487774210
# 8950                                                                      url,twitter.com/bryceabdo/status/1308743381099646976
# 8952                                                                      url,twitter.com/bryceabdo/status/1308778721797640195
# 9469                                                                url,twitter.com/malwrhunterteam/status/1318904041590718469
# 9469                                                                                      md5,45ed8898bead32070cf1eb25640b414c
# 9608                                                                                      md5,0224334fbec16d74b4101c270a3566bf
# 5323                                                                                                                       NaN
# 6531                                                                                                                       NaN
# 5306                                                                                      md5,eea4776399514664d888633ce72a2a8b
# 6321   url,blog.malwarebytes.com/threat-analysis/2020/06/multi-stage-apt-attack-drops-cobalt-strike-using-malleable-c2-feature
# 7987                                        url,sslbl.abuse.ch/ssl-certificates/sha1/ddb59d8cc93688bbf4925c7d27462b70e53225cb/
# 6255                                                                                      md5,9b0af1d42eb9d1e7033a958d5a0870c8
# 6389                                                                                                                       NaN
# 6391                                                                                                                       NaN
# 6393                                                                                                                       NaN
# 6400                                                                                                                       NaN
# 6399                                                                                                                       NaN
# 6395                                                                                                                       NaN
# 6396                                                                                                                       NaN
# 6398                                                                                                                       NaN
# 7484                                                                                      md5,f3ead1eef8ee0d3b4aceaef10b7b4a9c
# 6397                                                                                                                       NaN
# 6387                                                                                                                       NaN
# 6358                                              url,blog.talosintelligence.com/2020/06/indigodrop-maldocs-cobalt-strike.html
# 9707                                                              url,gist.github.com/aaronst/6aa7f61246f53a8dd4befea86e832456
# 9707                                                                                      md5,5c1fce8fa3e228b8f2641bb1f7a29c3f
# 9707                                                                                   url,www.youtube.com/watch?v=BhjQ6zsCVSc
# 9706                                                                                   url,www.youtube.com/watch?v=BhjQ6zsCVSc
# 9706                                                                                      md5,45ed8898bead32070cf1eb25640b414c
# 9493                                                                                   url,www.youtube.com/watch?v=BhjQ6zsCVSc
# 9493                                                                                      md5,45ed8898bead32070cf1eb25640b414c
# 10179                                                                                     md5,880a45ff31bc540e80ecf2cf93134c12
# 10179                                                             url,gist.github.com/aaronst/6aa7f61246f53a8dd4befea86e832456
# 10179                                                                                  url,www.youtube.com/watch?v=BhjQ6zsCVSc
# 7159                                                                                                                       NaN
# 7400                                                                                      md5,a26722fc7e5882b5a273239cddfe755f
# 7400                                                                                        url,attack.mitre.org/groups/G0080/
# 7456                                                                                      md5,69c6e302cc4394cae7ed8c6f7b288e92
# 7456                                                                                        url,attack.mitre.org/groups/G0080/
# 4579                                                                                        url,attack.mitre.org/groups/G0080/
# 4579                                                                                      md5,a26722fc7e5882b5a273239cddfe755f
# 4580                                                                                      md5,69c6e302cc4394cae7ed8c6f7b288e92
# 4580                                                                                        url,attack.mitre.org/groups/G0080/
# 10105                                                                                                                      NaN
#
#                           flow
# 25078  from_server,established
# 12076  established,from_server
# 12075    established,to_server
# 7681     established,to_server
# 9960     established,to_server
# 5406     established,to_server
# 5406     established,to_server
# 5404     established,to_server
# 5404     established,to_server
# 5327     established,to_server
# 5328     established,to_server
# 9958     established,to_server
# 9959     established,to_server
# 6316     established,to_server
# 6301     established,to_server
# 5210     established,to_server
# 6863                       NaN
# 5054     established,to_server
# 5054     established,to_server
# 5054     established,to_server
# 8749                       NaN
# 8749                       NaN
# 5235     established,to_client
# 10363    established,to_server
# 5954                       NaN
# 4767     established,to_server
# 10057    established,to_server
# 10058    established,to_server
# 6394     to_server,established
# 6392     to_server,established
# 10059    established,to_server
# 6390     to_server,established
# 10061    established,to_server
# 6388     to_server,established
# 6386     to_server,established
# 10060    established,to_server
# 10355                      NaN
# 10354    established,to_server
# 5953     established,to_client
# 8948     established,to_client
# 8950     established,to_client
# 8952     established,to_client
# 9469     established,to_client
# 9469     established,to_client
# 9608     established,to_client
# 5323     established,to_client
# 6531     established,to_client
# 5306     established,to_client
# 6321     established,to_client
# 7987   from_server,established
# 6255     established,to_client
# 6389   from_server,established
# 6391   from_server,established
# 6393   from_server,established
# 6400     established,to_client
# 6399     established,to_client
# 6395   from_server,established
# 6396     established,to_client
# 6398     established,to_client
# 7484     established,to_client
# 6397     established,to_client
# 6387   from_server,established
# 6358     established,to_client
# 9707     established,to_client
# 9707     established,to_client
# 9707     established,to_client
# 9706     established,to_client
# 9706     established,to_client
# 9493     established,to_client
# 9493     established,to_client
# 10179    established,to_client
# 10179    established,to_client
# 10179    established,to_client
# 7159   established,from_server
# 7400     established,to_server
# 7400     established,to_server
# 7456     established,to_server
# 7456     established,to_server
# 4579     established,to_client
# 4579     established,to_client
# 4580     established,to_client
# 4580     established,to_client
# 10105    established,to_server

# %% [markdown]
# Here we can see that many rules have multiple references. And, on that note, rules can hold a lot of interesting reading materials! How about we build a reading list.

# %%
sorted(
    list(
        RULES_COBALT_STRIKE \
            .loc[RULES_COBALT_STRIKE.fillna("NA") \
                                    .references.str.contains("^url")] \
            .references.unique()
    )
)
# Out:
# ['url,attack.mitre.org/groups/G0080/',
#  'url,blog.cobaltstrike.com/2015/10/07/named-pipe-pivoting/',
#  'url,blog.malwarebytes.com/threat-analysis/2020/06/multi-stage-apt-attack-drops-cobalt-strike-using-malleable-c2-feature',
#  'url,blog.talosintelligence.com/2020/06/indigodrop-maldocs-cobalt-strike.html',
#  'url,fireeye.com/blog/threat-research/2020/03/the-cycle-of-adversary-pursuit.html',
#  'url,gist.github.com/aaronst/6aa7f61246f53a8dd4befea86e832456',
#  'url,github.com//rsmudge/Malleable-C2-Profiles/blob/master/crimeware/magnitude.profile',
#  'url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/APT/havex.profile',
#  'url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/APT/meterpreter.profile',
#  'url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/onedrive_getonly.profile',
#  'url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/rtmp.profile',
#  'url,github.com/rsmudge/Malleable-C2-Profiles/blob/master/normal/safebrowsing.profile',
#  'url,github.com/xx0hcd/Malleable-C2-Profiles',
#  'url,posts.specterops.io/designing-peer-to-peer-command-and-control-ad2c61740456',
#  'url,sslbl.abuse.ch/ssl-certificates/sha1/ddb59d8cc93688bbf4925c7d27462b70e53225cb/',
#  'url,twitter.com/CyberRaiju/status/1249272772963864576',
#  'url,twitter.com/bryceabdo/status/1308743381099646976',
#  'url,twitter.com/bryceabdo/status/1308778721797640195',
#  'url,twitter.com/bryceabdo/status/1308802052487774210',
#  'url,twitter.com/malwrhunterteam/status/1318904041590718469',
#  'url,unit42.paloaltonetworks.com/solarstorm-supply-chain-attack-timeline',
#  'url,www.clearskysec.com/wp-content/uploads/2017/07/Operation_Wilted_Tulip.pdf',
#  'url,www.cobaltstrike.com/help-malleable-c2',
#  'url,www.youtube.com/watch?v=BhjQ6zsCVSc',
#  'url,www.youtube.com/watch?v=zAB5G-QOyx8']

# %% [markdown]
# But note that many links might be dead.
